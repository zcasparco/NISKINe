# %% [markdown]
# ## Application to a triangular array of moorings

# %%
import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
import cmocean
import niskine

import cartopy.crs as ccrs

# %%
#Directory
root_dir = '/Users/zcasparcohen/codes/NIW/data/'
figdir='/Users/zcasparcohen/codes/NIW/figures_vid/'

# %%
PI_omega = xr.open_dataarray(root_dir+'roms_energy_transfers_500m.nc') # energy transfers
ds_filt = xr.open_dataset(root_dir+'roms_filtered_500m.nc')  # low pass filtered velocity field
L = xr.open_dataset(root_dir+'roms_scales.nc')  # scales
midlon,midlat=PI_omega.lon.median(),PI_omega.lat.median() # central point (simulation grid)

# %%
ds_filt['ke_filtered'] = 0.5*(ds_filt.u_filtered**2+ds_filt.v_filtered**2) # KE frequencies < f
ds_filt['ke_high'] = 0.5*((ds_filt.u-ds_filt.u_filtered)**2+(ds_filt.v-ds_filt.v_filtered)**2) # KE frequencies > f

# %%
ds_mid,PI_mid = ds_filt.sel(lon=midlon,lat=midlat,method='nearest'),PI_omega.sel(lon=midlon,lat=midlat,method='nearest')

# %%
import pandas as pd
fig,ax=plt.subplots(3,1,figsize=(10,10),sharex=True)
PI_mid.plot(ax=ax[0],vmax=1e-6,cmap='coolwarm',cbar_kwargs={'label':r'$\Pi_{\omega}$ [m$^2$s$^{-3}$]'})
ds_mid.ke_filtered.plot(ax=ax[1],vmax=1e-1,cmap=cmocean.cm.solar,cbar_kwargs={'label':r'KE$_{low}$ [m$^2$s$^{-2}$]'})
ds_mid.ke_high.plot(ax=ax[2],vmax=1e-1,cmap=cmocean.cm.solar,cbar_kwargs={'label':r'KE$_{high}$ [m$^2$s$^{-2}$]'})
ax[0].set_xlim(np.datetime64('2001-01-07'),np.datetime64('2001-01-28'))
ax[0].set_title('Energy transfer')
ax[1].set_title('Low energy');ax[2].set_title('High energy')
for a in ax:
    a.axvline(np.datetime64('2001-01-08T00:00'),c='k',ls='--')

# %%
# Computing energy transfer rate
Sn = ds_filt.u_filtered.differentiate('x')-ds_filt.v_filtered.differentiate('y') #normal components of strain
S = ds_filt.u_filtered.differentiate('y')+ds_filt.v_filtered.differentiate('x') #shear component of strain
RV = ds_filt.v_filtered.differentiate('x')-ds_filt.u_filtered.differentiate('y')  #Relative vorticity
OW = Sn**2+S**2-RV**2 #OW parameter

# %%
OW_mid = OW.sel(lon=midlon,lat=midlat,method='nearest')
RV_mid = RV.sel(lon=midlon,lat=midlat,method='nearest')
#OW_mid = OW.interp(lon=midlon,lat=midlat)
#RV_mid = RV.interp(lon=midlon,lat=midlat)

# %%
def get_hist(ds,bins):
    """ get histograms times value to compare plot with Savage et al, 2025 (not published yet)
    ----------------------------------------------------
    Parameters:
    ds: xr.Dataset, contains variable to use for histogram
    bins:int, number of bins for histogram
    ----------------------------------------------------
    Returns:
    pdf_times_values:array, pdf x values
    bin_centers:array, histogram bins center for plot
    """
    # Flatten the 2D array to 1D
    flattened_data = ds.values.ravel()
    valid_data = flattened_data[~np.isnan(flattened_data)]
    # Compute histogram
    counts, bin_edges = np.histogram(valid_data, bins=bins, density=True)
    # Compute bin centers
    bin_centers = 0.5 * (bin_edges[:-1] + bin_edges[1:])
    # Compute PDF × value
    pdf_times_value = counts * np.abs(bin_centers)
    return pdf_times_value,bin_centers

def plot_hist(pi,ow,bins=50, plot=True):
    """ plot histograms times value to compare plot with Savage et al, 2025 (not published yet)
    ----------------------------------------------------
    Parameters:
    pi: xr.Dataset, contains energy transfer estimates to use for histogram
    ow: xr.Dataset, contains Okubo-Weiss parameter estimates to use for histogram plot
    bins:int, number of bins for histogram
    ----------------------------------------------------
    Returns:
    [hist_pos,hist_neg]: list of array, histograms for positive OW parameter
    [hist_pos_neg,hist_neg_neg]: list of array, histograms for negative OW parameter
    [bin_pos,bin_neg]: list of array, bins for positive OW parameter
    [bin_pos_neg,bin_neg_neg]: list of array, bins for negative OW parameter
    bin_centers:array, histogram bins center for plot
    """
    P_pos=pi.where((ow>0)&(pi>0))
    P_neg=pi.where((ow>0)&(pi<0))
    
    hist_pos,bin_pos = get_hist(P_pos,bins=bins)
    hist_neg,bin_neg = get_hist(P_neg,bins=bins)

    if plot:
    # Plot
        fig,axs=plt.subplots(1,2,figsize=(10,4),sharey=True)
        ax=axs[0]
        ax.plot(bin_pos, hist_pos, drawstyle='steps-mid', color='r', linewidth=2)
        ax.plot(-1*bin_neg, hist_neg, drawstyle='steps-mid', color='b', linewidth=2)
        ax.set_ylabel(r'PDf $\times$ $\Pi_\omega$ [m$^2$ s$^{-3}$]')
        ax.set_xlabel(r'$\Pi_\omega$ [m$^2$ s$^{-3}$]');ax.set_title(r'OW>0')
        ax.set_xlim(0,4e-6);#ax.set_ylim(0,None)
        ax.grid(True)
    
        P_pos=pi.where((ow<0)&(pi>0))
        P_neg=pi.where((ow<0)&(pi<0))
        
        hist_pos,bin_pos = get_hist(P_pos,bins=bins)
        hist_neg,bin_neg = get_hist(P_neg,bins=bins)
        
        # Plot
        ax=axs[1]
        ax.plot(bin_pos, hist_pos, drawstyle='steps-mid', color='r', linewidth=2,label=r'$\Pi_\omega>0$')
        ax.plot(-1*bin_neg, hist_neg, drawstyle='steps-mid', color='b', linewidth=2,label=r'$\Pi_\omega<0$')
        ax.set_ylabel(r'PDf $\times$ $\Pi_\omega$ [m$^2$ s$^{-3}$]')
        ax.set_xlabel(r'$\Pi_\omega$ [m$^2$ s$^{-3}$]');ax.set_title(r'OW<0')
        ax.set_xlim(0,4e-6);ax.set_ylim(0,0.4)
        ax.grid(True);ax.legend()
        return fig,axs
    else:
        P_pos_neg=pi.where((ow<0)&(pi>0))
        P_neg_neg=pi.where((ow<0)&(pi<0))
        
        hist_pos_neg,bin_pos_neg = get_hist(P_pos_neg,bins=bins)
        hist_neg_neg,bin_neg_neg = get_hist(P_neg_neg,bins=bins)
        return [hist_pos,hist_neg], [hist_pos_neg,hist_neg_neg], [bin_pos,bin_neg], [bin_pos_neg,bin_neg_neg]

# %%
fig,axs=plot_hist(PI_mid,OW_mid)
axs[0].set_xlim(0,1e-6)
axs[1].set_xlim(0,1e-6)
axs[1].set_ylim(0,0.6)
# Out:
# (0.0, 0.6)

# %%
#Load moorings config
conf = niskine.io.load_config()
m1lon, m1lat, m1bottom_depth = niskine.io.mooring_location(mooring=1)
m2lon, m2lat, m2bottom_depth = niskine.io.mooring_location(mooring=2)
m3lon, m3lat, m3bottom_depth = niskine.io.mooring_location(mooring=3)

def moorings_coords(lat,lon,midlat, midlon, ratio=1):
    """ define triangular mooring array coordinates around central latitude
    ----------------------------------------------------
    Parameters:
    lat: list, latitudes of NISKINe moorings
    lon: list, longitudes of NISKINe moorings
    midlat: float, central point latitude
    midlon: float, central point longitude
    ratio: float, 0<ratio<1, ratio to NISKINe moorings distance
    ----------------------------------------------------
    Returns:
    M1lat,M1lon: first mooring latitude and longitude
    M2lat,M2lon: second mooring latitude and longitude
    M3lat,M3lon: third mooring latitude and longitude
    """
    diff_lat = (lat[0]-lat[1])*ratio
    diff_lon = (lon[1]-lon[2])*ratio
    M1lat,M1lon = midlat+diff_lat/2, midlon+diff_lon/2
    M2lat,M2lon = midlat-diff_lat/2, midlon+diff_lon/2
    M3lat,M3lon = midlat, midlon-diff_lon/2
    return M1lat,M2lat,M3lat,M1lon,M2lon,M3lon

def get_center(lon,lat):
    
    """ Get central point coordinates from triangular mooring array
    ----------------------------------------------------
    Parameters:
    lat: list, latitudes of moorings
    lon: list, longitudes of moorings
    ----------------------------------------------------
    Returns:
    midlat: central point latitude
    midlon: central point longitude
    """
    #Coordinates of the center of the mooring array 
    latitudes = [m*np.pi/180 for m in lat]
    longitudes = [m*np.pi/180 for m in lon]
    sumx = np.sum(np.cos(latitudes)*np.cos(longitudes))/3
    sumy = np.sum(np.cos(latitudes)*np.sin(longitudes))/3
    sumz = np.sum(np.sin(latitudes))/3
    midlon = 180*np.arctan2(sumy,sumx)/np.pi
    hyp = np.sqrt(sumx*sumx+sumy*sumy)
    midlat = 180*np.arctan2(sumz,hyp)/np.pi
    return midlat,midlon

# %%
#Moorings coordinates:
M1lat,M2lat,M3lat,M1lon,M2lon,M3lon = moorings_coords([m1lat,m2lat,m3lat],[m1lon,m2lon,m3lon],midlat,midlon,ratio=1)
midlat1,midlon1 = get_center([M1lon,M2lon,M3lon],[M1lat,M2lat,M3lat])

# %%
fig, axs = plt.subplots(ncols=2,
                        subplot_kw={'projection': ccrs.LambertConformal(central_longitude=-27.4,central_latitude=61.5)},
                        figsize=(10,5))
ds_filt.ke_filtered.sel(depth=0,method='nearest').mean('time').plot.contourf(ax=axs[0],
                                                                             x='lon', y='lat',
                                                                             vmin=0, vmax=2e-1,
                                                                             cmap=cmocean.cm.solar,
                                                                             transform=ccrs.PlateCarree(),
                                                                            levels=51,
                                                                             add_labels=False,add_colorbar=True,
                                                                             cbar_kwargs={'label':r'Kinetic energy [m$^2$s$^{-2}$]','ticks':np.arange(0,5e-1,5e-2)})
ds_filt.ke_high.sel(depth=0,method='nearest').mean('time').plot.contourf(ax=axs[1],
                                                                             x='lon', y='lat',
                                                                             vmin=0, vmax=1e-1,
                                                                             cmap=cmocean.cm.solar,
                                                                             transform=ccrs.PlateCarree(),
                                                                            levels=51,
                                                                             add_labels=False,add_colorbar=True,
                                                                             cbar_kwargs={'label':r'Kinetic energy [m$^2$s$^{-2}$]','ticks':np.arange(0,5e-1,5e-2)})

for ax in axs:
    ax.scatter(midlon,midlat,transform=ccrs.PlateCarree());ax.scatter(M1lon,M1lat,c='g',transform=ccrs.PlateCarree());
    ax.scatter(M2lon,M2lat,c='g',transform=ccrs.PlateCarree());ax.scatter(M3lon,M3lat,c='g',transform=ccrs.PlateCarree())

# %%
# Select simulation gridpoint closest to central point or interpolate simulation outputs at central point
if True:
    ds_mid1,PI_mid1 = ds_filt.sel(lon=midlon1,lat=midlat1,method='nearest'),PI_omega.sel(lon=midlon1,lat=midlat1,method='nearest')
    OW_mid1 = OW.sel(lon=midlon1,lat=midlat1,method='nearest')
    RV_mid1 = RV.sel(lon=midlon1,lat=midlat1,method='nearest')

if False:
    ds_mid1,PI_mid1 = ds_filt.interp(lon=midlon1,lat=midlat1),PI_omega.interp(lon=midlon1,lat=midlat1)
    OW_mid1 = OW.interp(lon=midlon1,lat=midlat1)
    RV_mid1 = RV.interp(lon=midlon1,lat=midlat1)

# %%
PI_mid.sel(time=slice(None,'2001-01-15')).mean('time').plot(y='depth')
PI_mid1.sel(time=slice(None,'2001-01-15')).mean('time').plot(y='depth')

# %%
# Select simulation gridpoint closest to moorings coordinates or interpolate simulation outputs at morrings coordinates
if True:
    M1,PI_M1 = ds_filt.sel(lon=M1lon,lat=M1lat,method='nearest'),PI_omega.sel(lon=M1lon,lat=M1lat,method='nearest')
    M2,PI_M2 = ds_filt.sel(lon=M2lon,lat=M2lat,method='nearest'),PI_omega.sel(lon=M2lon,lat=M2lat,method='nearest')
    M3,PI_M3 = ds_filt.sel(lon=M3lon,lat=M3lat,method='nearest'),PI_omega.sel(lon=M3lon,lat=M3lat,method='nearest')

if False:
    M1,PI_M1 = ds_filt.interp(lon=M1lon,lat=M1lat),PI_omega.interp(lon=M1lon,lat=M1lat)
    M2,PI_M2 = ds_filt.interp(lon=M2lon,lat=M2lat),PI_omega.interp(lon=M2lon,lat=M2lat)
    M3,PI_M3 = ds_filt.interp(lon=M3lon,lat=M3lat),PI_omega.interp(lon=M3lon,lat=M3lat)

# %%
#Dict with moorings data
moorings={'1':M1,'2':M2,'3':M3}
PI_moorings={'1':PI_M1,'2':PI_M2,'3': PI_M3}

# %%
import gsw
import mplniw.utils as ut
import pandas as pd
def get_mid(moorings,mlat=midlat,mlon=midlon,col='usq'):
    """ Interpolate variable at the center  of the mooring triangular array using all moorings measurements.
    ----------------------------------------------------
    Parameters:
    moorings: dict, contains the three moorings xarray datasets
    col:str, variable to interpolate
    ----------------------------------------------------
    Returns:
    ds_mid:DataArray, interpolated variable
    """
    ds_mid = xr.combine_by_coords([moorings[k].expand_dims(['lon','lat']).drop(['x','y']) for k in moorings])
    #xr.merge([moorings[k][col] for k in moorings])
    ds_mid[col]=ds_mid[col].interpolate_na(dim='time',max_gap=pd.Timedelta('1D'))
    ds_mid[col]=ds_mid[col].fillna(0).interp(lat=mlat,lon=mlon,method='slinear')
    ds_mid[col]=ds_mid[col].where(ds_mid[col]!=0)
    return ds_mid[col]
def get_mid_IDW(moorings,mlat=midlat,mlon=midlon,col='u_filtered'):
    dM1,dM2,dM3 = [gsw.distance([mlon,moorings[k].lon],[mlat,moorings[k].lat]) for k in moorings]
    mid=(moorings['1'][col]/dM1+moorings['2'][col]/dM2+moorings['3'][col]/dM3)/(1/dM1+1/dM2+1/dM3)
    return mid,[dM1,dM2,dM3]
    
def transfers_moorings(mooring,pi,lats,lons,method='linear',mlat=midlat,mlon=midlon):
    # Computing distance and horizontal gradients (triangle approximation)
    M1lon,M2lon,M3lon=lons
    M1lat,M2lat,M3lat=lats
    dM1_N = gsw.distance([(M1lon+M3lon)/2,M1lon],[(M1lat+M3lat)/2,M1lat])
    dM3_N = gsw.distance([(M1lon+M3lon)/2,M3lon],[(M1lat+M3lat)/2,M3lat])
    dM3_S = gsw.distance([(M2lon+M3lon)/2,M3lon],[(M2lat+M3lat)/2,M3lat])
    dM2_S = gsw.distance([(M2lon+M3lon)/2,M2lon],[(M2lat+M3lat)/2,M2lat])
    
    dx_W = gsw.distance([mlon,M3lon],[mlat,mlat])
    dx_E = gsw.distance([mlon,(M1lon+M2lon)/2],[mlat,mlat])
    dy_NE = gsw.distance([mlon,midlon],[mlat,M1lat])
    dy_SE = gsw.distance([mlon,midlon],[mlat,M2lat])
    ueast = (moorings['1'].u_filtered*dy_SE+moorings['2'].u_filtered*dy_NE)/(dy_NE+dy_SE)
    veast = (moorings['1'].v_filtered*dy_SE+moorings['2'].v_filtered*dy_NE)/(dy_NE+dy_SE)
    uwest = moorings['3'].u_filtered
    vwest = moorings['3'].v_filtered
    unorth = (moorings['1'].u_filtered*dM3_N+moorings['3'].u_filtered*dM1_N)/(dM1_N+dM3_N)
    vnorth = (moorings['1'].v_filtered*dM3_N+moorings['3'].v_filtered*dM1_N)/(dM1_N+dM3_N)
    usouth = (moorings['2'].u_filtered*dM3_S+moorings['3'].u_filtered*dM2_S)/(dM2_S+dM3_S)
    vsouth = (moorings['2'].v_filtered*dM3_S+moorings['3'].v_filtered*dM2_S)/(dM2_S+dM3_S)
    ux = (ueast-uwest)/((dx_W+dx_E))
    vx = (veast-vwest)/((dx_W+dx_E))
    uy = (unorth-usouth)/((dy_NE+dy_SE)/2)
    vy = (vnorth-vsouth)/((dy_NE+dy_SE)/2)

    if method=='linear':
        # interpolating needed variables to the center of the square mooring array
        usqf_mid=get_mid(moorings,mlat=mlat,mlon=mlon,col='usq_filtered')  #filtered u squared
        vsqf_mid=get_mid(moorings,mlat=mlat,mlon=mlon,col='vsq_filtered')  #filtered v squared
        uvf_mid=get_mid(moorings,mlat=mlat,mlon=mlon,col='uv_filtered')    #filtered u*v
        uf_mid=get_mid(moorings,mlat=mlat,mlon=mlon,col='u_filtered')  #filtered u
        vf_mid=get_mid(moorings,mlat=mlat,mlon=mlon,col='v_filtered')  #filtered v
        usq_mid =get_mid(moorings,mlat=mlat,mlon=mlon,col='usq')   #raw u squared
        vsq_mid =get_mid(moorings,mlat=mlat,mlon=mlon,col='vsq')   #raw v squared
    elif method=='IDW':
        usqf_mid,_=get_mid_IDW(moorings,mlat=mlat,mlon=mlon,col='usq_filtered')  #filtered u squared
        vsqf_mid,_=get_mid_IDW(moorings,mlat=mlat,mlon=mlon,col='vsq_filtered')  #filtered v squared
        uvf_mid,_=get_mid_IDW(moorings,mlat=mlat,mlon=mlon,col='uv_filtered')    #filtered u*v
        uf_mid,_=get_mid_IDW(moorings,mlat=mlat,mlon=mlon,col='u_filtered')  #filtered u
        vf_mid,_=get_mid_IDW(moorings,mlat=mlat,mlon=mlon,col='v_filtered')  #filtered v
        usq_mid,_ =get_mid_IDW(moorings,mlat=mlat,mlon=mlon,col='usq')   #raw u squared
        vsq_mid,_ =get_mid_IDW(moorings,mlat=mlat,mlon=mlon,col='vsq')   #raw v squared
    # Computing energy transfer rate
    Sn_M = ux-vy #normal components of strain
    S_M = uy+vx #shear component of strain
    RV_M = vx-uy  #Relative vorticity
    OW_M = Sn_M**2+S_M**2-RV_M**2 #OW parameter
    P = -((usqf_mid-uf_mid**2)*ux + (vsqf_mid-vf_mid**2)*vy + (uvf_mid-uf_mid*vf_mid)*(uy+vx))
    P_mid = -((ds_mid.usq_filtered-ds_mid.u_filtered**2)*ux + (ds_mid.vsq_filtered-ds_mid.v_filtered**2)*vy + (ds_mid.uv_filtered-ds_mid.u_filtered*ds_mid.v_filtered)*(uy+vx))
    return P,P_mid,OW_M,RV_M

# %%
P,P_mid,OW_M,RV_M = transfers_moorings(moorings,PI_moorings,[M1lat,M2lat,M3lat],[M1lon,M2lon,M3lon],mlat=midlat1,mlon=midlon1)

# %%
fig,ax=plt.subplots(3,1,figsize=(12,10),sharex=True)
PI_mid.plot(ax=ax[0],vmax=1e-6,cmap='coolwarm',cbar_kwargs={'label':r'$\Pi_\omega$'})
P.plot(ax=ax[1],vmax=1e-6,cmap='coolwarm',cbar_kwargs={'label':r'$\Pi_\omega$'})
P_mid.plot(ax=ax[2],vmax=1e-6,cmap='coolwarm',cbar_kwargs={'label':r'$\Pi_\omega$'})
ax[0].set_title('Energy transfer, gridpoint')
ax[1].set_title('Energy transfer, 15km-triangle')
ax[2].set_title('Energy transfer, 15km-triangle+velocity gridpoint')
#((P-PI_mid)/PI_mid).plot(ax=ax[2],vmax=1)
# Out:
# Text(0.5, 1.0, 'Energy transfer, 15km-triangle+velocity gridpoint')

# %%
fig,axs=plot_hist(P,OW_M,bins=10)
for ax in axs:
    ax.set_xlim(0,1e-6)
axs[1].set_ylim(0,0.6);

fig,axs=plot_hist(P_mid,OW_M,bins=10)
for ax in axs:
    ax.set_xlim(0,1e-6)
axs[1].set_ylim(0,0.6)

fig,axs=plot_hist(PI_mid1,OW_mid1,bins=10)
for ax in axs:
    ax.set_xlim(0,1e-6)
axs[1].set_ylim(0,0.6)
fig,axs=plot_hist(PI_mid,OW_mid,bins=10)
for ax in axs:
    ax.set_xlim(0,1e-6)
axs[1].set_ylim(0,0.6)
# Out:
# (0.0, 0.6)

# %%
#Moorings coordinates:
M1lat,M2lat,M3lat,M1lon,M2lon,M3lon = moorings_coords([m1lat,m2lat,m3lat],[m1lon,m2lon,m3lon],midlat,midlon,ratio=1)
M1lat_25,M2lat_25,M3lat_25,M1lon_25,M2lon_25,M3lon_25 = moorings_coords([m1lat,m2lat,m3lat],[m1lon,m2lon,m3lon],midlat,midlon,ratio=0.25)
M1lat_05,M2lat_05,M3lat_05,M1lon_05,M2lon_05,M3lon_05 = moorings_coords([m1lat,m2lat,m3lat],[m1lon,m2lon,m3lon],midlat,midlon,ratio=0.5)
M1lat_15,M2lat_15,M3lat_15,M1lon_15,M2lon_15,M3lon_15 = moorings_coords([m1lat,m2lat,m3lat],[m1lon,m2lon,m3lon],midlat,midlon,ratio=1.5)
M1lat_2,M2lat_2,M3lat_2,M1lon_2,M2lon_2,M3lon_2 = moorings_coords([m1lat,m2lat,m3lat],[m1lon,m2lon,m3lon],midlat,midlon,ratio=2)

# %%
midlat_25,midlon_25 = get_center([M1lon_25,M2lon_25,M3lon_25],[M1lat_25,M2lat_25,M3lat_25])
midlat_05,midlon_05 = get_center([M1lon_05,M2lon_05,M3lon_05],[M1lat_05,M2lat_05,M3lat_05])
midlat_2,midlon_2 = get_center([M1lon_2,M2lon_2,M3lon_2],[M1lat_2,M2lat_2,M3lat_2])

# %%
if True:
    M1_25,PI_M1_25 = ds_filt.sel(lon=M1lon_25,lat=M1lat_25,method='nearest'),PI_omega.sel(lon=M1lon_25,lat=M1lat_25,method='nearest')
    M2_25,PI_M2_25 = ds_filt.sel(lon=M2lon_25,lat=M2lat_25,method='nearest'),PI_omega.sel(lon=M2lon_25,lat=M2lat_25,method='nearest')
    M3_25,PI_M3_25 = ds_filt.sel(lon=M3lon_25,lat=M3lat_25,method='nearest'),PI_omega.sel(lon=M3lon_25,lat=M3lat_25,method='nearest')

    M1_05,PI_M1_05 = ds_filt.sel(lon=M1lon_05,lat=M1lat_05,method='nearest'),PI_omega.sel(lon=M1lon_05,lat=M1lat_05,method='nearest')
    M2_05,PI_M2_05 = ds_filt.sel(lon=M2lon_05,lat=M2lat_05,method='nearest'),PI_omega.sel(lon=M2lon_05,lat=M2lat_05,method='nearest')
    M3_05,PI_M3_05 = ds_filt.sel(lon=M3lon_05,lat=M3lat_05,method='nearest'),PI_omega.sel(lon=M3lon_05,lat=M3lat_05,method='nearest')

    M1_15,PI_M1_15 = ds_filt.sel(lon=M1lon_15,lat=M1lat_15,method='nearest'),PI_omega.sel(lon=M1lon_15,lat=M1lat_15,method='nearest')
    M2_15,PI_M2_15 = ds_filt.sel(lon=M2lon_15,lat=M2lat_15,method='nearest'),PI_omega.sel(lon=M2lon_15,lat=M2lat_15,method='nearest')
    M3_15,PI_M3_15 = ds_filt.sel(lon=M3lon_15,lat=M3lat_15,method='nearest'),PI_omega.sel(lon=M3lon_15,lat=M3lat_15,method='nearest')

    M1_2,PI_M1_2 = ds_filt.sel(lon=M1lon_2,lat=M1lat_2,method='nearest'),PI_omega.sel(lon=M1lon_2,lat=M1lat_2,method='nearest')
    M2_2,PI_M2_2 = ds_filt.sel(lon=M2lon_2,lat=M2lat_2,method='nearest'),PI_omega.sel(lon=M2lon_2,lat=M2lat_2,method='nearest')
    M3_2,PI_M3_2 = ds_filt.sel(lon=M3lon_2,lat=M3lat_2,method='nearest'),PI_omega.sel(lon=M3lon_2,lat=M3lat_2,method='nearest')

if False:
    M1_05,PI_M1_05 = ds_filt.interp(lon=M1lon_05,lat=M1lat_05),PI_omega.interp(lon=M1lon_05,lat=M1lat_05)
    M2_05,PI_M2_05 = ds_filt.interp(lon=M2lon_05,lat=M2lat_05),PI_omega.interp(lon=M2lon_05,lat=M2lat_05)
    M3_05,PI_M3_05 = ds_filt.interp(lon=M3lon_05,lat=M3lat_05),PI_omega.interp(lon=M3lon_05,lat=M3lat_05)

    M1_15,PI_M1_15 = ds_filt.interp(lon=M1lon_15,lat=M1lat_15),PI_omega.interp(lon=M1lon_15,lat=M1lat_15)
    M2_15,PI_M2_15 = ds_filt.interp(lon=M2lon_15,lat=M2lat_15),PI_omega.interp(lon=M2lon_15,lat=M2lat_15)
    M3_15,PI_M3_15 = ds_filt.interp(lon=M3lon_15,lat=M3lat_15),PI_omega.interp(lon=M3lon_15,lat=M3lat_15)

    M1_2,PI_M1_2 = ds_filt.interp(lon=M1lon_2,lat=M1lat_2),PI_omega.interp(lon=M1lon_2,lat=M1lat_2)
    M2_2,PI_M2_2 = ds_filt.interp(lon=M2lon_2,lat=M2lat_2),PI_omega.interp(lon=M2lon_2,lat=M2lat_2)
    M3_2,PI_M3_2 = ds_filt.interp(lon=M3lon_2,lat=M3lat_2),PI_omega.interp(lon=M3lon_2,lat=M3lat_2)

# %%
moorings_25={'1':M1_25,'2':M2_25,'3':M3_25}
PI_moorings_25={'1':PI_M1_25,'2':PI_M2_25,'3': PI_M3_25}

moorings_05={'1':M1_05,'2':M2_05,'3':M3_05}
PI_moorings_05={'1':PI_M1_05,'2':PI_M2_05,'3': PI_M3_05}

moorings_15={'1':M1_15,'2':M2_15,'3':M3_15}
PI_moorings_15={'1':PI_M1_15,'2':PI_M2_15,'3': PI_M3_15}

moorings_2={'1':M1_2,'2':M2_2,'3':M3_2}
PI_moorings_2={'1':PI_M1_2,'2':PI_M2_2,'3': PI_M3_2}

# %%
P_25,P_mid_25,OW_M_25,RV_M_25 = transfers_moorings(moorings_25,PI_moorings_25,[M1lat_25,M2lat_25,M3lat_25],
                                                   [M1lon_25,M2lon_25,M3lon_25],mlat=midlat,mlon=midlon)
P_05,P_mid_05,OW_M_05,RV_M_05 = transfers_moorings(moorings_05,PI_moorings_05,[M1lat_05,M2lat_05,M3lat_05],
                                                   [M1lon_05,M2lon_05,M3lon_05],mlat=midlat,mlon=midlon)
P_15,P_mid_15,OW_M_15,RV_M_15 = transfers_moorings(moorings_15,PI_moorings_15,[M1lat_15,M2lat_15,M3lat_15],[M1lon_15,M2lon_15,M3lon_15])
P_2,P_mid_2,OW_M_2,RV_M_2 = transfers_moorings(moorings_2,PI_moorings_2,[M1lat_2,M2lat_2,M3lat_2],
                                               [M1lon_2,M2lon_2,M3lon_2],mlat=midlat,mlon=midlon)

# %%
ds_mid_05,PI_mid05 = ds_filt.sel(lon=midlon_05,lat=midlat_05,method='nearest'),PI_omega.sel(lon=midlon_05,lat=midlat_05,method='nearest')
ds_mid_2,PI_mid2 = ds_filt.sel(lon=midlon_2,lat=midlat_2,method='nearest'),PI_omega.sel(lon=midlon_2,lat=midlat_2,method='nearest')

# %%
fig,axs=plot_hist(P,OW_M,bins=50)
for ax in axs:
    ax.set_xlim(0,1e-6)
axs[1].set_ylim(0,0.4);
fig,axs=plot_hist(P_05,OW_M_05,bins=50)
for ax in axs:
    ax.set_xlim(0,1e-6)
axs[1].set_ylim(0,0.4);
fig,axs=plot_hist(PI_mid,OW_mid,bins=50)
for ax in axs:
    ax.set_xlim(0,1e-6)
axs[1].set_ylim(0,0.4);

# %%
PI_mid.sel(time=slice(None,'2001-01-25')).mean('depth').plot()
P_05.sel(time=slice(None,'2001-01-25')).mean('depth').plot()
P_mid_05.sel(time=slice(None,'2001-01-25')).mean('depth').plot(ls='--')
P.sel(time=slice(None,'2001-01-25')).mean('depth').plot()
P_mid.sel(time=slice(None,'2001-01-25')).mean('depth').plot(ls='--')

# %%
PI_mid.plot.hist(bins=50)
P.plot.hist(bins=50,alpha=0.5)
plt.axvline(PI_mid.mean())
plt.axvline(P.mean(),c='k')

# %%
fig, axs = plt.subplots(ncols=1,
                        subplot_kw={'projection': ccrs.LambertConformal(central_longitude=-27.4,central_latitude=61.5)},
                        figsize=(5,5))
ds_filt.ke_filtered.sel(depth=0,method='nearest').mean('time').plot.contourf(ax=axs,
                                                                             x='lon', y='lat',
                                                                             vmin=0, vmax=2e-1,
                                                                             cmap=cmocean.cm.solar,
                                                                             transform=ccrs.PlateCarree(),
                                                                            levels=51,
                                                                             add_labels=False,add_colorbar=True,
                                                                             cbar_kwargs={'label':r'Kinetic energy [m$^2$s$^{-2}$]','ticks':np.arange(0,5e-1,5e-2)})
ax=axs
ax.scatter(midlon,midlat,transform=ccrs.PlateCarree(),c='k');ax.scatter(M1lon,M1lat,c='r',transform=ccrs.PlateCarree());
ax.scatter(M2lon,M2lat,c='r',transform=ccrs.PlateCarree());ax.scatter(M3lon,M3lat,c='r',transform=ccrs.PlateCarree());
ax.scatter(M1lon_05,M1lat_05,c='b',transform=ccrs.PlateCarree());
ax.scatter(M2lon_05,M2lat_05,c='b',transform=ccrs.PlateCarree());ax.scatter(M3lon_05,M3lat_05,c='b',transform=ccrs.PlateCarree())
ax.scatter(M1lon_2,M1lat_2,c='g',transform=ccrs.PlateCarree());
ax.scatter(M2lon_2,M2lat_2,c='g',transform=ccrs.PlateCarree());ax.scatter(M3lon_2,M3lat_2,c='g',transform=ccrs.PlateCarree())
    #ax.scatter(midlon1,midlat1,transform=ccrs.PlateCarree(),c='r')

# %%
P_hist,P_bins = get_hist(P,bins=50)
Pmid_hist,Pmid_bins = get_hist(P_mid,bins=50)
P05mid_hist,P05mid_bins = get_hist(P_mid_05,bins=50)
P05_hist,P05_bins = get_hist(P_05,bins=50)
P15mid_hist,P15mid_bins = get_hist(P_mid_15,bins=50)
P15_hist,P15_bins = get_hist(P_15,bins=50)
P2mid_hist,P2mid_bins = get_hist(P_mid_2,bins=50)
P2_hist,P2_bins = get_hist(P_2,bins=50)
PImid_hist,PImid_bins = get_hist(PI_mid,bins=50)
PImid1_hist,PImid1_bins = get_hist(PI_mid1,bins=50)
PImid05_hist,PImid05_bins = get_hist(PI_mid05,bins=50)
PImid2_hist,PImid2_bins = get_hist(PI_mid2,bins=50)

# %%
fig,axs=plt.subplots(1,3,figsize=(15,5))
ax=axs[0]
#ax.plot(P15_bins,P15_hist,drawstyle='steps-mid',c='g',label='23.5km')
ax.plot(P2_bins,P2_hist,drawstyle='steps-mid',c='g',label='30km')
ax.plot(P_bins,P_hist,drawstyle='steps-mid',c='r',label='15km')
ax.plot(P05_bins,P05_hist,drawstyle='steps-mid',c='b',label='7.5km')
ax.plot(PImid_bins,PImid_hist,drawstyle='steps-mid',c='k',label='Truth')
ax.legend()

ax=axs[1]
ax.plot(Pmid_bins,Pmid_hist,drawstyle='steps-mid',c='r',ls='-.',label='15km, interpolated (u,v)')
ax.plot(P_bins,P_hist,drawstyle='steps-mid',c='r',label='15km')
ax.plot(PImid_bins,PImid_hist,drawstyle='steps-mid',c='k')
ax.legend(loc=2)
ax=axs[2]
ax.plot(P05mid_bins,P05mid_hist,drawstyle='steps-mid',c='b',ls='-.',label='7.5km, interpolated (u,v)')
ax.plot(P05_bins,P05_hist,drawstyle='steps-mid',c='b',label='7.5km')
ax.plot(PImid_bins,PImid_hist,drawstyle='steps-mid',c='k')
ax.legend(loc=2)
for ax in axs:
    ax.grid();ax.set_xlim(-4e-6,4e-6);

fig,axs=plt.subplots(1,3,figsize=(15,5))
ax=axs[0]
ax.plot(Pmid_bins,Pmid_hist,drawstyle='steps-mid',c='r',ls='-.',label='15km')
ax.plot(P_bins,P_hist,drawstyle='steps-mid',c='r',label='15km')
ax.plot(PImid1_bins,PImid1_hist,drawstyle='steps-mid',c='k',label='Truth')
ax.legend()

ax=axs[1]
ax.plot(P05mid_bins,P05mid_hist,drawstyle='steps-mid',c='b',ls='-.',label='7.5km')
ax.plot(P05_bins,P05_hist,drawstyle='steps-mid',c='b',label='7.5km')
ax.plot(PImid05_bins,PImid05_hist,drawstyle='steps-mid',c='k',label='Truth')
ax.legend(loc=2)
ax=axs[2]
ax.plot(P2mid_bins,P2mid_hist,drawstyle='steps-mid',c='g',ls='-.',label='30km')
ax.plot(P2_bins,P2_hist,drawstyle='steps-mid',c='g',label='30km')
ax.plot(PImid2_bins,PImid2_hist,drawstyle='steps-mid',c='k',label='Truth')
ax.legend(loc=2)
for ax in axs:
    ax.grid();ax.set_xlim(-4e-6,4e-6);

# %%
import scipy
fig,axs=plt.subplots(1,3,figsize=(15,5))
ax=axs[0]
#ax.scatter(0.5,np.abs(P_05).mean(),c='b')
#ax.scatter(0.5,np.abs(P_mid_05).mean(),c='b',marker='x')
#ax.scatter(1,np.abs(P).mean(),c='r')
#ax.scatter(1,np.abs(P_mid).mean(),c='r',marker='x')
#ax.axhline(np.abs(PI_mid).mean(),c='k',ls='--')
#ax.set_title('Mean absolute energy transfer')

ax.scatter(0.5,(P_05).mean(),c='b')
ax.scatter(0.5,(P_mid_05).mean(),c='b',marker='x')
#ax.scatter(1.5,(P_15).mean(),c='g')
ax.scatter(2,(P_2).mean(),c='g')
#ax.scatter(1.5,(P_mid_15).mean(),c='g',marker='x')
ax.scatter(2,(P_mid_2).mean(),c='g',marker='x')
ax.scatter(1,(P).mean(),c='r')
ax.scatter(1,(P_mid).mean(),c='r',marker='x')
ax.axhline((PI_mid).mean(),c='k',ls='--')
ax.set_title('Mean energy transfer')


ax=axs[1]
ax.scatter(0.5,P_05.std(),c='b')
ax.scatter(0.5,P_mid_05.std(),c='b',marker='x')
#ax.scatter(1.5,(P_15).std(),c='g')
#ax.scatter(1.5,(P_mid_15).std(),c='g',marker='x')
ax.scatter(2,(P_2).std(),c='g')
ax.scatter(2,(P_mid_2).std(),c='g',marker='x')
ax.scatter(1,P.std(),c='r')
ax.scatter(1,P_mid.std(),c='r',marker='x')
ax.axhline(PI_mid.std(),c='k',ls='--');
ax.set_title('Energy transfer standard deviation');

ax=axs[2]
ax.scatter(0.5,scipy.stats.skew(P_05.values.flatten()),c='b')
ax.scatter(0.5,scipy.stats.skew(P_mid_05.values.flatten()),c='b',marker='x')
#ax.scatter(1.5,scipy.stats.skew(P_15.values.flatten()),c='g')
#ax.scatter(1.5,scipy.stats.skew(P_mid_15.values.flatten()),c='g',marker='x')
ax.scatter(2,scipy.stats.skew(P_2.values.flatten()),c='g')
ax.scatter(2,scipy.stats.skew(P_mid_2.values.flatten()),c='g',marker='x')
ax.scatter(1,scipy.stats.skew(P.values.flatten()),c='r')
ax.scatter(1,scipy.stats.skew(P_mid.values.flatten()),c='r',marker='x')
ax.axhline(scipy.stats.skew(PI_mid.values.flatten()),c='k',ls='--');
ax.set_title('Energy transfer skewness');

# %%
scipy.stats.skew(P_05.where(OW_M_05>0,drop=True).fillna(0).values.flatten())
# Out:
# -4.717560542859263

# %%
import scipy
fig,axs=plt.subplots(1,3,figsize=(15,5))
ax=axs[0]
ax.scatter(0.5,(P_05.where(OW_M_05>0)).mean(),c='b')
#ax.scatter(1.5,(P_15).mean(),c='g')
ax.scatter(2,(P_2.where(OW_M_2>0)).mean(),c='g')
ax.scatter(1,(P.where(OW_M>0)).mean(),c='r')
ax.axhline((PI_mid.where(OW_mid>0)).mean(),c='k',ls='--')

ax.scatter(0.5,(P_05.where(OW_M_05<0)).mean(),c='b',marker='s')
#ax.scatter(1.5,(P_15).mean(),c='g')
ax.scatter(2,(P_2.where(OW_M_2<0)).mean(),c='g',marker='s')
ax.scatter(1,(P.where(OW_M<0)).mean(),c='r',marker='s')
ax.axhline((PI_mid.where(OW_mid<0)).mean(),c='k',ls='-.')
ax.set_title('Mean energy transfer')


ax=axs[1]
ax.scatter(0.5,P_05.where(OW_M_05>0).std(),c='b')
#ax.scatter(1.5,(P_15).std(),c='g')
ax.scatter(2,(P_2.where(OW_M_2>0)).std(),c='g')
ax.scatter(1,P.where(OW_M>0).std(),c='r')
ax.axhline(PI_mid.where(OW_mid>0).std(),c='k',ls='--');

ax.scatter(0.5,P_05.where(OW_M_05<0).std(),c='b',marker='s')
#ax.scatter(1.5,(P_15).std(),c='g')
ax.scatter(2,(P_2.where(OW_M_2<0)).std(),c='g',marker='s')
ax.scatter(1,P.where(OW_M<0).std(),c='r',marker='s')
ax.axhline(PI_mid.where(OW_mid<0).std(),c='k',ls='-.');

ax.set_title('Energy transfer standard deviation');

ax=axs[2]
ax.scatter(0.5,scipy.stats.skew(P_05.where(OW_M_05>0,drop=True).fillna(0).values.flatten()),c='b')
#ax.scatter(1.5,scipy.stats.skew(P_15.values.flatten()),c='g')
ax.scatter(2,scipy.stats.skew(P_2.where(OW_M_2>0,drop=True).fillna(0).values.flatten()),c='g')
ax.scatter(1,scipy.stats.skew(P.where(OW_M>0,drop=True).fillna(0).values.flatten()),c='r')
ax.axhline(scipy.stats.skew(PI_mid.where(OW_mid>0,drop=True).fillna(0).values.flatten()),c='k',ls='--');

ax.scatter(0.5,scipy.stats.skew(P_05.where(OW_M_05<0,drop=True).fillna(0).values.flatten()),c='b',marker='s')
#ax.scatter(1.5,scipy.stats.skew(P_15.values.flatten()),c='g')
ax.scatter(2,scipy.stats.skew(P_2.where(OW_M_2<0,drop=True).fillna(0).values.flatten()),c='g',marker='s')
ax.scatter(1,scipy.stats.skew(P.where(OW_M<0,drop=True).fillna(0).values.flatten()),c='r',marker='s')
ax.axhline(scipy.stats.skew(PI_mid.where(OW_mid<0,drop=True).fillna(0).values.flatten()),c='k',ls='-.');

ax.set_title('Energy transfer skewness');

# %%
fig,axs=plt.subplots(3,2,figsize=(20,10),sharex=True)
ax=axs[0,0]
M1_05.u_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)
ax=axs[1,0]
M2_05.u_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)
ax=axs[2,0]
M3_05.u_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)

ax=axs[0,1]
M1_05.v_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)
ax=axs[1,1]
M2_05.v_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)
ax=axs[2,1]
M3_05.v_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)

fig,axs=plt.subplots(3,2,figsize=(20,10),sharex=True)
ax=axs[0,0]
M1_2.u_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)
ax=axs[1,0]
M2_2.u_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)
ax=axs[2,0]
M3_2.u_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)

ax=axs[0,1]
M1_2.v_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)
ax=axs[1,1]
M2_2.v_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)
ax=axs[2,1]
M3_2.v_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)

# %%
uM,dM = get_mid_IDW(moorings,mlat=midlat,mlon=midlon,col='u_filtered')
usqM,dM = get_mid_IDW(moorings,mlat=midlat,mlon=midlon,col='usq_filtered')

uM_l = get_mid(moorings,mlat=midlat,mlon=midlon,col='u_filtered')
usqM_l = get_mid(moorings,mlat=midlat,mlon=midlon,col='usq_filtered')

uM_05,dM_05 = get_mid_IDW(moorings_05,mlat=midlat,mlon=midlon,col='vsq_filtered')
uM_2,dM_2 = get_mid_IDW(moorings_2,mlat=midlat,mlon=midlon,col='vsq_filtered')

# %%
fig,axs=plt.subplots(2,1,figsize=(12,6),sharex=True)
ax=axs[0]
(usqM-uM**2).plot(ax=ax,vmax=0.4)

ax=axs[1]
(usqM_l-uM_l**2).plot(ax=ax,vmax=0.4)

# %%
fig,axs=plt.subplots(3,1,figsize=(12,10),sharex=True)
ax=axs[0]
ds_mid.u_filtered.sel(time=slice(None,'2001-01-25')).plot(ax=ax)
ax=axs[1]
uM.sel(time=slice(None,'2001-01-25')).plot(ax=ax)
ax=axs[2]
get_mid(moorings,mlat=midlat,mlon=midlon,col='v_filtered').sel(time=slice(None,'2001-01-25')).plot(ax=ax)

# %%
Pbis,Pbis_mid,OWbis_M,RVbis_M = transfers_moorings(moorings,PI_moorings,[M1lat,M2lat,M3lat],[M1lon,M2lon,M3lon],method='IDW')
Pbis_05,Pbis_mid_05,OWbis_M_05,RVbis_M_05 = transfers_moorings(moorings_05,PI_moorings_05,[M1lat_05,M2lat_05,M3lat_05],[M1lon_05,M2lon_05,M3lon_05],method='IDW')
Pbis_2,Pbis_mid_2,OWbis_M_2,RVbis_M_2 = transfers_moorings(moorings_2,PI_moorings_2,[M1lat_2,M2lat_2,M3lat_2],[M1lon_2,M2lon_2,M3lon_2],method='IDW')

# %%
Pbis_hist,Pbis_bins = get_hist(Pbis,bins=50)
Pbismid_hist,Pbismid_bins = get_hist(Pbis_mid,bins=50)
#P05mid_hist,P05mid_bins = get_hist(P_mid_05,bins=50)
#P05_hist,P05_bins = get_hist(P_05,bins=50)
#P15mid_hist,P15mid_bins = get_hist(P_mid_15,bins=50)
#P15_hist,P15_bins = get_hist(P_15,bins=50)
#P2mid_hist,P2mid_bins = get_hist(P_mid_2,bins=50)
#P2_hist,P2_bins = get_hist(P_2,bins=50)
#PImid_hist,PImid_bins = get_hist(PI_mid,bins=50)

# %%
fig,ax=plt.subplots()
ax.plot(P_bins,P_hist,drawstyle='steps-mid',c='r',label='15km: spline')
ax.plot(Pbis_bins,Pbis_hist,drawstyle='steps-mid',c='r',label='15km: IDW',ls='-.')
ax.plot(Pmid_bins,Pmid_hist,drawstyle='steps-mid',c='r',label='15km: gridpoint',ls=':')
ax.plot(PImid_bins,PImid_hist,drawstyle='steps-mid',c='k',label='Truth')
ax.legend();ax.set_xlim(-0.4e-5,0.4e-5);ax.grid()

# %%
 fig,axs=plt.subplots(1,3,figsize=(15,5))
ax=axs[0]

ax.scatter(0.5,(P_05).mean(),c='b')
ax.scatter(0.5,(Pbis_05).mean(),c='b',marker='v')
ax.scatter(0.5,(P_mid_05).mean(),c='b',marker='x')
ax.scatter(2,(P_2).mean(),c='g')
ax.scatter(2,(Pbis_2).mean(),c='g',marker='v')
ax.scatter(2,(P_mid_2).mean(),c='g',marker='x')
ax.scatter(1,(P).mean(),c='r')
ax.scatter(1,(Pbis).mean(),c='r',marker='v')
ax.scatter(1,(P_mid).mean(),c='r',marker='x')
ax.axhline(PI_mid.mean(),c='k',ls='--');
#ax.axhline(PI_mid1.mean(),c='r',ls='--');
#ax.axhline(PI_mid05.mean(),c='b',ls='--');
#ax.axhline(PI_mid2.mean(),c='g',ls='--');
ax.set_title('Mean energy transfer')


ax=axs[1]
ax.scatter(0.5,(P_05).std(),c='b')
ax.scatter(0.5,(Pbis_05).std(),c='b',marker='v')
ax.scatter(0.5,(P_mid_05).std(),c='b',marker='x')
ax.scatter(2,(P_2).std(),c='g')
ax.scatter(2,(Pbis_2).std(),c='g',marker='v')
ax.scatter(2,(P_mid_2).std(),c='g',marker='x')
ax.scatter(1,P.std(),c='r')
ax.scatter(1,Pbis.std(),c='r',marker='v')
ax.scatter(1,P_mid.std(),c='r',marker='x')
ax.axhline(PI_mid.std(),c='k',ls='--');
#ax.axhline(PI_mid1.std(),c='r',ls='--');
#ax.axhline(PI_mid05.std(),c='b',ls='--');
#ax.axhline(PI_mid2.std(),c='g',ls='--');
ax.set_title('Energy transfer standard deviation');

ax=axs[2]
ax.scatter(0.5,scipy.stats.skew(P_05.values.flatten()),c='b')
ax.scatter(0.5,scipy.stats.skew(Pbis_05.values.flatten()),c='b',marker='v')
ax.scatter(0.5,scipy.stats.skew(P_mid_05.values.flatten()),c='b',marker='x')
ax.scatter(2,scipy.stats.skew(P_2.values.flatten()),c='g')
ax.scatter(2,scipy.stats.skew(Pbis_2.values.flatten()),c='g',marker='v')
ax.scatter(2,scipy.stats.skew(P_mid_2.values.flatten()),c='g',marker='x')
ax.scatter(1,scipy.stats.skew(P.values.flatten()),c='r')
ax.scatter(1,scipy.stats.skew(Pbis.values.flatten()),c='r',marker='v')
ax.scatter(1,scipy.stats.skew(P_mid.values.flatten()),c='r',marker='x')
ax.axhline(scipy.stats.skew(PI_mid.values.flatten()),c='k',ls='--');
#ax.axhline(scipy.stats.skew(PI_mid1.values.flatten()),c='r',ls='--');
#ax.axhline(scipy.stats.skew(PI_mid05.values.flatten()),c='b',ls='--');
#ax.axhline(scipy.stats.skew(PI_mid2.values.flatten()),c='g',ls='--');
ax.set_title('Energy transfer skewness');

# %%
fig,axs=plt.subplots(1,3,figsize=(15,5))
ax=axs[0]
ax.scatter(0.5,(Pbis_05.where(OWbis_M_05>0)).mean(),c='b',marker='^')
#ax.scatter(1.5,(P_15).mean(),c='g')
ax.scatter(2,(Pbis_2.where(OWbis_M_2>0)).mean(),c='g',marker='^')
ax.scatter(1,(Pbis.where(OWbis_M>0)).mean(),c='r',marker='^')
ax.axhline((PI_mid.where(OW_mid>0)).mean(),c='k',ls='--')

ax.scatter(0.5,(Pbis_05.where(OWbis_M_05<0)).mean(),c='b',marker='v')
#ax.scatter(1.5,(P_15).mean(),c='g')
ax.scatter(2,(Pbis_2.where(OWbis_M_2<0)).mean(),c='g',marker='v')
ax.scatter(1,(Pbis.where(OWbis_M<0)).mean(),c='r',marker='v')
ax.axhline((PI_mid.where(OW_mid<0)).mean(),c='k',ls='-.')
ax.set_title('Mean energy transfer')


ax=axs[1]
ax.scatter(0.5,Pbis_05.where(OWbis_M_05>0).std(),c='b',marker='^')
#ax.scatter(1.5,(P_15).std(),c='g')
ax.scatter(2,(Pbis_2.where(OWbis_M_2>0)).std(),c='g',marker='^')
ax.scatter(1,Pbis.where(OWbis_M>0).std(),c='r',marker='^')
ax.axhline(PI_mid.where(OW_mid>0).std(),c='k',ls='--');

ax.scatter(0.5,Pbis_05.where(OWbis_M_05<0).std(),c='b',marker='v')
#ax.scatter(1.5,(P_15).std(),c='g')
ax.scatter(2,(Pbis_2.where(OWbis_M_2<0)).std(),c='g',marker='v')
ax.scatter(1,Pbis.where(OWbis_M<0).std(),c='r',marker='v')
ax.axhline(PI_mid.where(OW_mid<0).std(),c='k',ls='-.');

ax.set_title('Energy transfer standard deviation');

ax=axs[2]
ax.scatter(0.5,scipy.stats.skew(Pbis_05.where(OWbis_M_05>0,drop=True).fillna(0).values.flatten()),c='b',marker='^')
ax.scatter(0.5,scipy.stats.skew(P_05.where(OW_M_05>0,drop=True).fillna(0).values.flatten()),c='b',marker='^',ls=':')
#ax.scatter(1.5,scipy.stats.skew(P_15.values.flatten()),c='g')
ax.scatter(2,scipy.stats.skew(Pbis_2.where(OWbis_M_2>0,drop=True).fillna(0).values.flatten()),c='g',marker='^')
ax.scatter(2,scipy.stats.skew(P_2.where(OW_M_2>0,drop=True).fillna(0).values.flatten()),c='g',marker='^',ls=':')
ax.scatter(1,scipy.stats.skew(Pbis.where(OWbis_M>0,drop=True).fillna(0).values.flatten()),c='r',marker='^')
ax.scatter(1,scipy.stats.skew(P.where(OW_M>0,drop=True).fillna(0).values.flatten()),c='r',marker='^',ls=':')
ax.axhline(scipy.stats.skew(PI_mid.where(OW_mid>0,drop=True).fillna(0).values.flatten()),c='k',ls='--');

ax.scatter(0.5,scipy.stats.skew(Pbis_05.where(OWbis_M_05<0,drop=True).fillna(0).values.flatten()),c='b',marker='v')
ax.scatter(0.5,scipy.stats.skew(P_05.where(OW_M_05<0,drop=True).fillna(0).values.flatten()),c='b',marker='v',ls=':')
#ax.scatter(1.5,scipy.stats.skew(P_15.values.flatten()),c='g')
ax.scatter(2,scipy.stats.skew(Pbis_2.where(OWbis_M_2<0,drop=True).fillna(0).values.flatten()),c='g',marker='v')
ax.scatter(2,scipy.stats.skew(P_2.where(OW_M_2<0,drop=True).fillna(0).values.flatten()),c='g',marker='v',ls=':')
ax.scatter(1,scipy.stats.skew(Pbis.where(OWbis_M<0,drop=True).fillna(0).values.flatten()),c='r',marker='v')
ax.scatter(1,scipy.stats.skew(P.where(OW_M<0,drop=True).fillna(0).values.flatten()),c='r',marker='v',ls=':')

ax.axhline(scipy.stats.skew(PI_mid.where(OW_mid<0,drop=True).fillna(0).values.flatten()),c='k',ls='-.');

ax.set_title('Energy transfer skewness');

# %%
# Why is the mean better when distance is higher?
fig,axs=plt.subplots(4,1,figsize=(10,15),sharex=True)
ds_mid.u_filtered.sel(lon=midlon,lat=midlat).sel(time=slice(None,'2001-01-25')).plot(ax=axs[0],vmax=5e-5)
RV_M_05.sel(time=slice(None,'2001-01-25')).plot(ax=axs[1],vmax=5e-5)
RV_M.sel(time=slice(None,'2001-01-25')).plot(ax=axs[2],vmax=5e-5)
RV_M_15.sel(time=slice(None,'2001-01-25')).plot(ax=axs[3],vmax=5e-5)
axs[1].set_title('Distance:7.5km');axs[0].set_title('Truth')
axs[2].set_title('Distance:15km');axs[3].set_title('Distance:20km')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 3
#       1 # Why is the mean better when distance is higher?
#       2 fig,axs=plt.subplots(4,1,figsize=(10,15),sharex=True)
# ----> 3 ds_mid.u_filtered.sel(lon=midlon,lat=midlat).sel(time=slice(None,'2001-01-25')).plot(ax=axs[0],vmax=5e-5)
#       4 RV_M_05.sel(time=slice(None,'2001-01-25')).plot(ax=axs[1],vmax=5e-5)
#       5 RV_M.sel(time=slice(None,'2001-01-25')).plot(ax=axs[2],vmax=5e-5)
#
# File ~/miniconda3/envs/mpl_niw/lib/python3.11/site-packages/xarray/core/dataarray.py:1550, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1440 def sel(
#    1441     self: T_DataArray,
#    1442     indexers: Mapping[Any, Any] | None = None,
#    (...)
#    1446     **indexers_kwargs: Any,
#    1447 ) -> T_DataArray:
# ...

# %%
# Why is the mean better when distance is higher?
fig,axs=plt.subplots(4,1,figsize=(10,15),sharex=True)
PI_mid.sel(time=slice(None,'2001-01-25')).plot(ax=axs[0],vmax=5e-7)
P_05.sel(time=slice(None,'2001-01-25')).plot(ax=axs[1],vmax=5e-7)
P.sel(time=slice(None,'2001-01-25')).plot(ax=axs[2],vmax=5e-7)
P_15.sel(time=slice(None,'2001-01-25')).plot(ax=axs[3],vmax=5e-7)
axs[1].set_title('Distance:7.5km');
axs[2].set_title('Distance:15km');axs[3].set_title('Distance:20km')
# Out:
# Text(0.5, 1.0, 'Distance:20km')

# %%
# Why is the mean better when distance is higher?
fig,axs=plt.subplots(4,1,figsize=(10,15),sharex=True)
RV.sel(lon=midlon,lat=midlat).sel(time=slice(None,'2001-01-25')).plot(ax=axs[0],vmax=5e-5)
RV_M_05.sel(time=slice(None,'2001-01-25')).plot(ax=axs[1],vmax=5e-5)
RV_M.sel(time=slice(None,'2001-01-25')).plot(ax=axs[2],vmax=5e-5)
RV_M_15.sel(time=slice(None,'2001-01-25')).plot(ax=axs[3],vmax=5e-5)
axs[1].set_title('Distance:7.5km');axs[0].set_title('Truth')
axs[2].set_title('Distance:15km');axs[3].set_title('Distance:20km')
# Out:
# Text(0.5, 1.0, 'Distance:20km')

# %%
fig,axs=plt.subplots(3,1,figsize=(10,12),sharex=True)
((RV_M_05-RV.sel(lon=midlon,lat=midlat))/RV.sel(lon=midlon,lat=midlat)).sel(time=slice(None,'2001-01-25')).plot(ax=axs[0],vmax=1)
((RV_M-RV.sel(lon=midlon,lat=midlat))/RV.sel(lon=midlon,lat=midlat)).sel(time=slice(None,'2001-01-25')).plot(ax=axs[1],vmax=1)
((RV_M_15-RV.sel(lon=midlon,lat=midlat))/RV.sel(lon=midlon,lat=midlat)).sel(time=slice(None,'2001-01-25')).plot(ax=axs[2],vmax=1)
#RV_M.sel(time=slice(None,'2001-01-25')).plot(ax=axs[1])
#RV_M_05.sel(time=slice(None,'2001-01-25')).plot(ax=axs[2])
#RV_M_15.sel(time=slice(None,'2001-01-25')).plot(ax=axs[3])

# %%
fig,axs=plt.subplots(4,1,figsize=(10,15),sharex=True)
OW_mid.sel(time=slice(None,'2001-01-25')).plot(ax=axs[0],vmax=5e-9)
OW_M_05.sel(time=slice(None,'2001-01-25')).plot(ax=axs[1],vmax=5e-9)
OW_M.sel(time=slice(None,'2001-01-25')).plot(ax=axs[2],vmax=5e-9)
OW_M_15.sel(time=slice(None,'2001-01-25')).plot(ax=axs[3],vmax=5e-9)
axs[1].set_title('Distance:7.5km');
axs[2].set_title('Distance:15km');axs[3].set_title('Distance:20km')
# Out:
# Text(0.5, 1.0, 'Distance:20km')

# %% [markdown]
# ### Averaging methods

# %%
def vec(p1, p2):
        return (p2[0] - p1[0], p2[1] - p1[1])
triangle = ((M1lat, M1lon),  # M1
        (M2lat, M2lon),  # M2
        (M3lat, M3lon)   # M3
           )

# %%
def point_in_triangle(x,y,triangle):
    (x1, y1), (x2, y2), (x3, y3) = triangle
    v0 = vec((x1, y1), (x3, y3))
    v1 = vec((x1, y1), (x1, y2))
    v2 = vec((x1, y1),(x,y))
    d00 = np.dot(v0,v0)
    d01 = np.dot(v0,v1)
    d11 = np.dot(v1,v1)
    d20 = np.dot(v2,v0)
    d21 = np.dot(v2,v1)
    denom = d00 * d11 - d01 * d01;
    v = (d11 * d20 - d01 * d21) / denom;
    w = (d00 * d21 - d01 * d20) / denom;
    u = 1 - v - w;
    return u,v,w
#    xr.Dataset({'u':(['x','y'],np.array([[u]])),'v':(['x','y'],np.array([[v]])),'w':(['x','y'],np.array([[w]]))},
#                      coords={'x':np.array([x]),'y':np.array([y])})

# %%
fig, axs = plt.subplots(ncols=1,
                        subplot_kw={'projection': ccrs.LambertConformal(central_longitude=-27.4,central_latitude=61.5)},
                        figsize=(5,5))
ds_filt.ke_filtered.sel(depth=0,method='nearest').mean('time').plot.contourf(ax=axs,
                                                                             x='lon', y='lat',
                                                                             vmin=0, vmax=2e-1,
                                                                             cmap=cmocean.cm.solar,
                                                                             transform=ccrs.PlateCarree(),
                                                                            levels=51,
                                                                             add_labels=False,add_colorbar=True,
                                                                             cbar_kwargs={'label':r'Kinetic energy [m$^2$s$^{-2}$]','ticks':np.arange(0,5e-1,5e-2)})
ax=axs
ax.scatter(M2lon,M2lat,c='r',transform=ccrs.PlateCarree());ax.scatter(M3lon,M3lat,c='r',transform=ccrs.PlateCarree());
ax.scatter(M1lon,M1lat,c='r',transform=ccrs.PlateCarree());
ax.scatter(midlon1,midlat1,transform=ccrs.PlateCarree(),c='k')

# %%
triangle = ((PI_M1.x, PI_M1.y),  # M1
        (PI_M2.x, PI_M2.y),  # M2
        (PI_M3.x, PI_M3.y)   # M3
           )


u=point_in_triangle(PI_mid.x.values,PI_mid.y.values,triangle)

# %%
def barycentric_coords(X,Y,triangle):
    #(lat1, lon1), (lat2, lon2), (lat3, lon3) = latlon
    _u = [[point_in_triangle(x,y,triangle)[0] for x in X] for y in Y]
    _v = [[point_in_triangle(x,y,triangle)[1] for x in X] for y in Y]
    _w = [[point_in_triangle(x,y,triangle)[2] for x in X] for y in Y]
    ds_out = xr.Dataset({'u':(['lon','lat'],np.array(_u).T),'v':(['lon','lat'],np.array(_v).T),'w':(['lon','lat'],np.array(_w).T)},
                        coords={'lon':(['lon'],np.array(X.lon)),'lat':(['lat'],np.array(Y.lat))})
    return ds_out
def get_avg(moorings,col='usq_filtered'):
    ds_mid = xr.combine_by_coords([moorings[k].expand_dims(['lon','lat']).drop(['x','y']) for k in moorings])
    return ds_mid[col].mean(['lon','lat'])
    
def transfers_avg(pi,moorings,M,triangle,triangle_latlon):
    (lat1, lon1), (lat2, lon2), (lat3, lon3) = triangle_latlon
    X = pi.x.where((pi.lon<=max(lon1,lon2)+0.05)&(pi.lon>=lon3-0.05),drop=True)
    Y =pi.y.where((pi.lat<=lat1+0.05)&(pi.lat>=lat2-0.05),drop=True)
    ds_bcoords = barycentric_coords(X,Y,triangle)
    mask = ds_bcoords.where((ds_bcoords.u>=0)&(ds_bcoords.v>=0)&(ds_bcoords.w>=0)&(ds_bcoords.u<=1)&(ds_bcoords.v<=1)&(ds_bcoords.w<=1))
    PI_avg = pi.where(np.isnan(mask.u)==False).mean(['lon','lat'])
    L_avg = L.where(np.isnan(mask.u)==False).mean(['lon','lat'])
    KEh_avg = ds_filt.ke_high.where(np.isnan(mask.u)==False).mean(['lon','lat'])
    KEf_avg = ds_filt.ke_filtered.where(np.isnan(mask.u)==False).mean(['lon','lat'])
    #ds_moorings = xr.combine_by_coords([moorings[k].expand_dims(['lon','lat']) for k in moorings])
    #(x1,y1),(x2,y2),(x3,y3) = triangle
    p1,p2,p3 = triangle
    m1,m2,m3 = M
    u1,v1 = m1.u_filtered,m1.v_filtered
    u2,v2 = m2.u_filtered, m2.v_filtered
    u3,v3 = m3.u_filtered, m3.v_filtered
    A = np.c_[np.array([p1,p2,p3]), np.ones(3)]  # shape: (3, 3)
    A_inv = np.linalg.pinv(A)                # pseudo-inverse for least squares

    # Stack values into a 3 x (time, depth) array
    F = xr.concat([u1,u2,u3], dim="point")  # shape: (point=3, time, depth)
    Fv = xr.concat([v1,v2,v3], dim="point")  # shape: (point=3, time, depth)
    
    # Compute coefficients (a, b, c) per (time, depth)
    coef = xr.apply_ufunc(
            lambda f: A_inv @ f,
            F,
            input_core_dims=[["point"]],
            output_core_dims=[["coeff"]],
            vectorize=True,
            dask="parallelized",
            output_dtypes=[float]
        )
    
    coefv = xr.apply_ufunc(
            lambda f: A_inv @ f,
            Fv,
            input_core_dims=[["point"]],
            output_core_dims=[["coeff"]],
            vectorize=True,
            dask="parallelized",
            output_dtypes=[float]
        )
    ux=coef.sel(coeff=0).sel(time=slice(None,'2001-01-25'))
    uy=coef.sel(coeff=1).sel(time=slice(None,'2001-01-25'))
    vx=coefv.sel(coeff=0).sel(time=slice(None,'2001-01-25'))
    vy=coefv.sel(coeff=1).sel(time=slice(None,'2001-01-25'))
    usqf_avg = get_avg(moorings,col='usq_filtered').sel(time=slice(None,'2001-01-25'))
    vsqf_avg = get_avg(moorings,col='vsq_filtered').sel(time=slice(None,'2001-01-25'))
    uf_avg = get_avg(moorings,col='u_filtered').sel(time=slice(None,'2001-01-25'))
    vf_avg = get_avg(moorings,col='v_filtered').sel(time=slice(None,'2001-01-25'))
    uvf_avg = get_avg(moorings,col='uv_filtered').sel(time=slice(None,'2001-01-25'))
    # Computing energy transfer rate
    Sn = ux-vy #normal components of strain
    S = uy+vx #shear component of strain
    RV = vx-uy  #Relative vorticity
    OW = Sn**2+S**2-RV**2 #OW parameter
    P_avg = -((usqf_avg-uf_avg**2)*ux + (vsqf_avg-vf_avg**2)*vy + (uvf_avg-uf_avg*vf_avg)*(uy+vx))
    return KEh_avg,KEf_avg,PI_avg,P_avg,OW,RV,L_avg

# %%
triangle_latlon = ((PI_M1.lat, PI_M1.lon),  # M1
        (PI_M2.lat, PI_M2.lon),  # M2
        (PI_M3.lat, PI_M3.lon))   # M3
                   
KEh_avg,KEf_avg,PI_avg,P_avg,OW_avg,RV_avg,L_avg = transfers_avg(PI_omega,moorings,[M1,M2,M3],triangle,triangle_latlon)
PI_avg=PI_avg.sel(time=slice(None,'2001-01-25'))
L_avg=L_avg.sel(time=slice(None,'2001-01-25'))
KEh_avg=KEh_avg.sel(time=slice(None,'2001-01-25'))
KEf_avg=KEf_avg.sel(time=slice(None,'2001-01-25'))

# %%
#ratio=0.5
triangle_05 = ((PI_M1_05.x, PI_M1_05.y),  # M1
        (PI_M2_05.x, PI_M2_05.y),  # M2
        (PI_M3_05.x, PI_M3_05.y)   # M3
           )
triangle_latlon_05 = ((PI_M1_05.lat, PI_M1_05.lon),  # M1
        (PI_M2_05.lat, PI_M2_05.lon),  # M2
        (PI_M3_05.lat, PI_M3_05.lon))   # M3

KEh_avg05,KEf_avg05,PI_avg05,P_avg05,OW_avg05,RV_avg05,L_avg05 = transfers_avg(PI_omega,moorings_05,[M1_05,M2_05,M3_05]
                                                                       ,triangle_05,triangle_latlon_05)
PI_avg05=PI_avg05.sel(time=slice(None,'2001-01-25'))
L_avg05=L_avg05.sel(time=slice(None,'2001-01-25'))
KEh_avg05=KEh_avg05.sel(time=slice(None,'2001-01-25'))
KEf_avg05=KEf_avg05.sel(time=slice(None,'2001-01-25'))

# %%
#ratio=0.25
triangle_25 = ((PI_M1_25.x, PI_M1_25.y),  # M1
        (PI_M2_25.x, PI_M2_25.y),  # M2
        (PI_M3_25.x, PI_M3_25.y)   # M3
           )
triangle_latlon_25 = ((PI_M1_25.lat, PI_M1_25.lon),  # M1
        (PI_M2_25.lat, PI_M2_25.lon),  # M2
        (PI_M3_25.lat, PI_M3_25.lon))   # M3

KEh_avg25,KEf_avg25,PI_avg25,P_avg25,OW_avg25,RV_avg25,L_avg25 = transfers_avg(PI_omega,moorings_25,[M1_25,M2_25,M3_25]
                                                                       ,triangle_25,triangle_latlon_25)
PI_avg25=PI_avg25.sel(time=slice(None,'2001-01-25'))
L_avg25=L_avg25.sel(time=slice(None,'2001-01-25'))
KEh_avg25=KEh_avg25.sel(time=slice(None,'2001-01-25'))
KEf_avg25=KEf_avg25.sel(time=slice(None,'2001-01-25'))

# %%
#ratio=2
triangle_2 = ((PI_M1_2.x, PI_M1_2.y),  # M1
        (PI_M2_2.x, PI_M2_2.y),  # M2
        (PI_M3_2.x, PI_M3_2.y)   # M3
           )
triangle_latlon_2 = ((PI_M1_2.lat, PI_M1_2.lon),  # M1
        (PI_M2_2.lat, PI_M2_2.lon),  # M2
        (PI_M3_2.lat, PI_M3_2.lon))   # M3

KEh_avg2,KEf_avg2,PI_avg2,P_avg2,OW_avg2,RV_avg2,L_avg2 = transfers_avg(PI_omega,moorings_2,[M1_2,M2_2,M3_2]
                                                                       ,triangle_2,triangle_latlon_2)
PI_avg2=PI_avg2.sel(time=slice(None,'2001-01-25'))
L_avg2=L_avg2.sel(time=slice(None,'2001-01-25'))
KEh_avg2=KEh_avg2.sel(time=slice(None,'2001-01-25'))
KEf_avg2=KEf_avg2.sel(time=slice(None,'2001-01-25'))

# %%
fig,axs=plt.subplots(2,1,figsize=(12,8),sharex=True)
PI_mid1.plot(ax=axs[0],vmax=1e-6,cbar_kwargs={'label':r'$\Pi_\omega$'})
P.plot(ax=axs[1],vmax=1e-6,cbar_kwargs={'label':r'$\Pi_\omega$'})
axs[0].set_title('Full model')
axs[1].set_title('Mooring-like: 15km')
# Out:
# Text(0.5, 1.0, 'Mooring-like: 15km')

# %%
fig,axs=plt.subplots(2,1,figsize=(12,8),sharex=True)
PI_avg.plot(ax=axs[0],vmax=1e-6,cbar_kwargs={'label':r'$\Pi_\omega$'})
P_avg.plot(ax=axs[1],vmax=1e-6,cbar_kwargs={'label':r'$\Pi_\omega$'})
axs[0].set_title('Full model')
axs[1].set_title('Mooring-like: 15km')

fig,axs=plt.subplots(2,1,figsize=(12,8),sharex=True)
PI_avg05.plot(ax=axs[0],vmax=1e-6,cbar_kwargs={'label':r'$\Pi_\omega$'})
P_avg05.plot(ax=axs[1],vmax=1e-6,cbar_kwargs={'label':r'$\Pi_\omega$'})
axs[0].set_title('Full model')
axs[1].set_title('Mooring-like: 7.5km')

fig,axs=plt.subplots(2,1,figsize=(12,8),sharex=True)
PI_avg2.plot(ax=axs[0],vmax=1e-6,cbar_kwargs={'label':r'$\Pi_\omega$'})
P_avg2.plot(ax=axs[1],vmax=1e-6,cbar_kwargs={'label':r'$\Pi_\omega$'})
axs[0].set_title('Full model')
axs[1].set_title('Mooring-like: 7.5km')
# Out:
# Text(0.5, 1.0, 'Mooring-like: 7.5km')

# %%
fig,axs = plt.subplots(1,2,figsize=(10,5))
ax=axs[0]
_=PI_avg.plot.hist(ax=ax,bins=80,color='k',label='Model')
_=P_avg.plot.hist(ax=ax,bins=80,alpha=0.5,color='r',label='Moorings')
ax.set_xlim(-1e-6,1e-6);ax.legend();ax.grid()
ax=axs[1]
PI_avg.mean('time').plot(ax=ax,y='depth',c='k')
P_avg.mean('time').plot(ax=ax,y='depth',c='r')
ax.grid();ax.set_title('Time-mean vertical profile')
#ax1=ax.twiny()
#KEh_avg.mean('time').plot(ax=ax1,y='depth')
#KEf_avg.mean('time').plot(ax=ax1,y='depth')
ax.set_ylim(-1000,0);#ax1.set_xlim(0,0.06)
fig.suptitle('Average: model vs 15km')
fig.tight_layout()

fig,axs = plt.subplots(1,2,figsize=(10,5))
ax=axs[0]
_=PI_mid1.plot.hist(ax=ax,bins=80,color='k',label='Model')
_=P.plot.hist(ax=ax,bins=80,alpha=0.5,color='r',label='Moorings')
ax.set_xlim(-1e-6,1e-6);ax.legend();ax.grid()
ax=axs[1]
PI_mid1.mean('time').plot(ax=ax,y='depth',c='k')
P.mean('time').plot(ax=ax,y='depth',c='r')
ax.grid();ax.set_title('Time-mean vertical profile')

#ax1=ax.twiny()
#KEh_avg.mean('time').plot(ax=ax1,y='depth')
#KEf_avg.mean('time').plot(ax=ax1,y='depth')
ax.set_ylim(-1000,0);#ax1.set_xlim(0,0.06)
fig.suptitle('Interpolation: model vs 15km')
fig.tight_layout()

# %%
fig,axs = plt.subplots(1,3,figsize=(10,5),sharey=True)
ax=axs[1]
PI_avg.mean('time').plot(ax=ax,y='depth',c='k')
P_avg.mean('time').plot(ax=ax,y='depth',c='r')
ax=axs[0]
PI_avg05.mean('time').plot(ax=ax,y='depth',c='k')
P_avg05.mean('time').plot(ax=ax,y='depth',c='b')
ax=axs[2]
PI_avg2.mean('time').plot(ax=ax,y='depth',c='k')
P_avg2.mean('time').plot(ax=ax,y='depth',c='g')
for ax,km in zip(axs,['7.5km','15km','30km']):
    ax.grid();ax.set_xlim(-2e-7,1e-7);
    ax.set_ylim(-1000,0);ax.set_ylabel('');
    ax.set_title('Mooring array: '+km)
fig.tight_layout()

fig,axs = plt.subplots(1,3,figsize=(10,5),sharey=True)
ax=axs[0]
_=PI_avg05.plot.hist(ax=ax,bins=80,color='k',label='Model')
_=P_avg05.plot.hist(ax=ax,bins=80,alpha=0.5,color='b',label='Moorings')
ax=axs[1]
_=PI_avg.plot.hist(ax=ax,bins=80,color='k',label='Model')
_=P_avg.plot.hist(ax=ax,bins=80,alpha=0.5,color='r',label='Moorings')
ax=axs[2]
_=PI_avg2.plot.hist(ax=ax,bins=80,color='k',label='Model')
_=P_avg2.plot.hist(ax=ax,bins=80,alpha=0.5,color='g',label='Moorings')
for ax in axs:
    ax.set_xlim(-1e-6,1e-6);ax.legend();ax.grid()

fig.tight_layout()

# %%
fig,axs = plt.subplots(1,3,figsize=(10,5),sharey=True)
ax=axs[1]
PI_mid.mean('time').plot(ax=ax,y='depth',c='k')
P_mid.mean('time').plot(ax=ax,y='depth',c='r')
ax=axs[0]
PI_mid05.mean('time').plot(ax=ax,y='depth',c='k')
P_mid_05.mean('time').plot(ax=ax,y='depth',c='b')
ax=axs[2]
PI_mid2.mean('time').plot(ax=ax,y='depth',c='k')
P_mid_2.mean('time').plot(ax=ax,y='depth',c='g')
for ax,km in zip(axs,['7.5km','15km','30km']):
    ax.grid();ax.set_xlim(-2e-7,1e-7)
    ax.set_ylim(-1000,0);ax.set_ylabel('');
    ax.set_title('Mooring array: '+km)
fig.tight_layout()

fig,axs = plt.subplots(1,3,figsize=(10,5),sharey=True)
ax=axs[0]
_=PI_mid05.plot.hist(ax=ax,bins=80,color='k',label='Model')
_=P_mid_05.plot.hist(ax=ax,bins=80,alpha=0.5,color='b',label='Moorings')
ax=axs[1]
_=PI_mid1.plot.hist(ax=ax,bins=80,color='k',label='Model')
_=P_mid.plot.hist(ax=ax,bins=80,alpha=0.5,color='r',label='Moorings')
ax=axs[2]
_=PI_mid2.plot.hist(ax=ax,bins=80,color='k',label='Model')
_=P_mid_2.plot.hist(ax=ax,bins=80,alpha=0.5,color='g',label='Moorings')
for ax in axs:
    ax.set_xlim(-1e-6,1e-6);ax.legend();ax.grid();
    ax.set_title('')

fig.tight_layout()

# %%
#Average method
fig,axs=plt.subplots(1,3,figsize=(15,5))
ax=axs[0]
ax.scatter(PI_avg.mean(),(P_avg.mean()-PI_avg.mean()),c='r',marker='o',label='15km')
ax.scatter(PI_avg05.mean(),(P_avg05.mean()-PI_avg05.mean()),c='b',marker='o',label='7.5km')
ax.scatter(PI_avg2.mean(),(P_avg2.mean()-PI_avg2.mean()),c='g',marker='o',label='30km')
ax.grid();ax.axhline(0,c='k',ls='--');ax.set_xlabel('True value');ax.legend()
ax.set_title('Mean energy transfer');ax.set_ylabel('Difference to truth (moorings - true value)')

ax=axs[1]
ax.scatter(PI_avg.std(),(P_avg.std()-PI_avg.std()),c='r',marker='o')
ax.scatter(PI_avg05.std(),(P_avg05.std()-PI_avg05.std()),c='b',marker='o')
ax.scatter(PI_avg2.std(),(P_avg2.std()-PI_avg2.std()),c='g',marker='o')
ax.grid();ax.axhline(0,c='k',ls='--');ax.set_xlabel('True value')
ax.set_title('Energy transfer standard deviation')

ax=axs[2]
ax.scatter(scipy.stats.skew(PI_avg.fillna(0).values.flatten()),(scipy.stats.skew(P_avg.fillna(0).values.flatten())-scipy.stats.skew(PI_avg.fillna(0).values.flatten())),c='r',marker='o')
ax.scatter(scipy.stats.skew(PI_avg05.fillna(0).values.flatten()),(scipy.stats.skew(P_avg05.fillna(0).values.flatten())-scipy.stats.skew(PI_avg05.fillna(0).values.flatten())),c='b',marker='o')
ax.scatter(scipy.stats.skew(PI_avg2.fillna(0).values.flatten()),(scipy.stats.skew(P_avg2.fillna(0).values.flatten())-scipy.stats.skew(PI_avg2.fillna(0).values.flatten())),c='g',marker='o')
ax.grid();ax.axhline(0,c='k',ls='--');ax.set_xlabel('True value')
ax.set_title('Energy transfer skewness')
fig.suptitle('Average')

#Interpolation method
fig,axs=plt.subplots(1,3,figsize=(15,5))
ax=axs[0]
ax.scatter(PI_mid1.mean(),(P_mid.mean()-PI_mid1.mean()),c='r',marker='o',label='15km')
ax.scatter(PI_mid05.mean(),(P_mid_05.mean()-PI_mid05.mean()),c='b',marker='o',label='7.5km')
ax.scatter(PI_mid2.mean(),(P_mid_2.mean()-PI_mid2.mean()),c='g',marker='o',label='30km')
ax.grid();ax.axhline(0,c='k',ls='--');ax.set_xlabel('True value');ax.legend()
ax.set_title('Mean energy transfer');ax.set_ylabel('Difference to truth (moorings - true value)')

ax=axs[1]
ax.scatter(PI_mid1.std(),(P_mid.std()-PI_mid1.std()),c='r',marker='o')
ax.scatter(PI_mid05.std(),(P_mid_05.std()-PI_mid05.std()),c='b',marker='o')
ax.scatter(PI_mid2.std(),(P_mid_2.std()-PI_mid2.std()),c='g',marker='o')
ax.grid();ax.axhline(0,c='k',ls='--');ax.set_xlabel('True value')
ax.set_title('Energy transfer standard deviation')

ax=axs[2]
ax.scatter(scipy.stats.skew(PI_mid1.fillna(0).values.flatten()),(scipy.stats.skew(P_mid.fillna(0).values.flatten())-scipy.stats.skew(PI_mid1.fillna(0).values.flatten())),c='r',marker='o')
ax.scatter(scipy.stats.skew(PI_mid05.fillna(0).values.flatten()),(scipy.stats.skew(P_mid_05.fillna(0).values.flatten())-scipy.stats.skew(PI_mid05.fillna(0).values.flatten())),c='b',marker='o')
ax.scatter(scipy.stats.skew(PI_mid2.fillna(0).values.flatten()),(scipy.stats.skew(P_mid_2.fillna(0).values.flatten())-scipy.stats.skew(PI_mid2.fillna(0).values.flatten())),c='g',marker='o')
ax.grid();ax.axhline(0,c='k',ls='--');ax.set_xlabel('True value')
ax.set_title('Energy transfer skewness')
fig.suptitle('Interpolation')
# Out:
# Text(0.5, 0.98, 'Interpolation')

# %% [markdown]
# Average method seem to give better results in terms of comparison to the full simulation ouptuts. Except for the skewness. There is no wrong sign of skewness with the interpolation method while the skewness sign is false with the average method for 30km between points.

# %% [markdown]
# ### Comparison to scales
# $\textbf{1/ NIW horizontal wavelength:}$
#
# $\lambda_h = \lambda_v\frac{N}{\sqrt{\omega^2-f^2}}$
#
# $\lambda_v$: vertical wavelength
#
# $\omega$: NIW frequency
#
# f: Coriolis frequency
#
# N: Buoyancy frequency
#
#
# $\textbf{2/Barotropic deformation radius:}$
#
# $\sqrt{gH}/f$
#
# with H the seabed depth
#
#
# $\textbf{3/Baroclinic deformation radius:}$
#
# $\frac{NH}{n\pi f}$
#
# n: baroclinic mode

# %%
print('Barotropic deformation radius:',np.around(L_avg.Lr.values*1e-3,2),' km')
# Out:
# Barotropic deformation radius: 957.33  km

# %%
L_avg
# Out:
# <xarray.Dataset>
# Dimensions:  (lv: 2, time: 464, depth: 53, mode: 3)
# Coordinates:
#   * time     (time) datetime64[ns] 2001-01-06T16:00:00 ... 2001-01-25T23:00:00
#   * depth    (depth) float64 -3.5 -7.0 -11.0 -15.5 ... -890.5 -938.0 -987.0
#   * lv       (lv) int64 100 600
#   * mode     (mode) int64 1 2 3
# Data variables:
#     l_IW     (lv, time, depth) float64 3.008e+03 6.303e+03 ... 6.722e+04
#     Lr_bc    (mode, time, depth) float64 2.095e+03 4.305e+03 ... 2.54e+03
#     Lr       float64 9.573e+05

# %%
fig,axs=plt.subplots(1,3,figsize=(15,5))
ax=axs[0]
ax.scatter(PI_avg.mean(),(P_avg.mean()-PI_avg.mean()),c='r',marker='o',label='15km')
ax.scatter(PI_avg05.mean(),(P_avg05.mean()-PI_avg05.mean()),c='b',marker='o',label='7.5km')
ax.scatter(PI_avg2.mean(),(P_avg2.mean()-PI_avg2.mean()),c='g',marker='o',label='30km')
#ax.text(-1.5e-8,1.26e-8,'Mode 1, Lr = %s km'%np.around(1e-3*L_avg.Lr_bc.sel(mode=1).mean().values,2),c='r')
#ax.text(-1.5e-8,1.13e-8,'Mode 1, Lr = %s km'%np.around(1e-3*L_avg05.Lr_bc.sel(mode=1).mean().values,2),c='b')
#ax.text(-1.5e-8,1e-8,'Mode 1, Lr = %s km'%np.around(1e-3*L_avg2.Lr_bc.sel(mode=1).mean().values,2),c='g')
ax.text(-1.5e-8,1.26e-8,r'$\lambda_v$ = 100m, $\lambda_h \simeq$  %s km'%np.around(1e-3*L_avg.l_IW.sel(lv=100).mean().values,2),c='r')
ax.text(-1.5e-8,1.13e-8,r'$\lambda_v$ = 100m, $\lambda_h \simeq$  %s km'%np.around(1e-3*L_avg05.l_IW.sel(lv=100).mean().values,2),c='b')
ax.text(-1.5e-8,1e-8,r'$\lambda_v$ = 100m, $\lambda_h \simeq$  %s km'%np.around(1e-3*L_avg2.l_IW.sel(lv=100).mean().values,2),c='g')
ax.grid();ax.axhline(0,c='k',ls='--');ax.set_xlabel('True value');ax.legend()
ax.set_title('Mean ');ax.set_ylabel('Difference to truth (moorings - true value)')

ax=axs[1]
ax.scatter(PI_avg.std(),(P_avg.std()-PI_avg.std()),c='r',marker='o')
ax.scatter(PI_avg05.std(),(P_avg05.std()-PI_avg05.std()),c='b',marker='o')
ax.scatter(PI_avg2.std(),(P_avg2.std()-PI_avg2.std()),c='g',marker='o')
ax.grid();ax.axhline(0,c='k',ls='--');ax.set_xlabel('True value')
ax.set_title('Standard deviation')

ax=axs[2]
ax.scatter(scipy.stats.skew(PI_avg.fillna(0).values.flatten()),(scipy.stats.skew(P_avg.fillna(0).values.flatten())-scipy.stats.skew(PI_avg.fillna(0).values.flatten())),c='r',marker='o')
ax.scatter(scipy.stats.skew(PI_avg05.fillna(0).values.flatten()),(scipy.stats.skew(P_avg05.fillna(0).values.flatten())-scipy.stats.skew(PI_avg05.fillna(0).values.flatten())),c='b',marker='o')
ax.scatter(scipy.stats.skew(PI_avg2.fillna(0).values.flatten()),(scipy.stats.skew(P_avg2.fillna(0).values.flatten())-scipy.stats.skew(PI_avg2.fillna(0).values.flatten())),c='g',marker='o')
ax.grid();ax.axhline(0,c='k',ls='--');ax.set_xlabel('True value')
ax.set_title('Skewness')
# Out:
# Text(0.5, 1.0, 'Skewness')

# %%
X = [L_avg05.Lr_bc.sel(mode=1).mean(),L_avg.Lr_bc.sel(mode=1).mean(),L_avg2.Lr_bc.sel(mode=1).mean()]
Y = [L_avg05.l_IW.isel(lv=0).mean(),L_avg.l_IW.isel(lv=0).mean(),L_avg2.l_IW.isel(lv=0).mean()]
Xbis = [L_avg05.Lr_bc.mean(),L_avg.Lr_bc.mean(),L_avg2.Lr_bc.mean()]
Ybis = [L_avg05.l_IW.isel().mean(),L_avg.l_IW.mean(),L_avg2.l_IW.mean()]

# %%
fig,ax=plt.subplots(figsize=(4,4))
ax.scatter([x*1e-3 for x in X],[y*1e-3 for y in Y],c=['b','r','g'])
ax.grid();ax.set_ylabel(r'$\lambda_h$ [km]');
ax.set_xlabel(r'Deformation radius (mode 1) [km]')
#plt.figure()
#plt.scatter(Xbis,Ybis,c=['b','r','g'],marker='v')
#plt.grid()
# Out:
# Text(0.5, 0, 'Deformation radius (mode 1) [km]')

# %% [markdown]
# ## Dev

# %%
fig,axs=plt.subplots(3,1,figsize=(12,9),sharex=True)
KEf_avg.plot(ax=axs[0],cmap=cmocean.cm.solar,vmax=0.4)
KEh_avg.plot(ax=axs[1],cmap=cmocean.cm.solar,vmax=0.4)
PI_avg.plot(vmax=1e-6,ax=axs[2],cmap=cmocean.cm.balance)
for ax in axs:
    ax.axvline(np.datetime64('2001-01-19'),ls='--',c='c')
    ax.axvline(np.datetime64('2001-01-15'),ls='--',c='orange')

# %%
f1 = 24*3600*ut.coriolis(M1lat_2)/(2*np.pi)
f2 = 24*3600*ut.coriolis(M2lat_2)/(2*np.pi)
f3 = 24*3600*ut.coriolis(M3lat_2)/(2*np.pi)

# %%
t1 = '2001-01-15'
fig,axs=plt.subplots(3,1,figsize=(12,9),sharex=True)
(M1_2.u-M1_2.u_filtered).sel(time=slice(None,t1)).plot(ax=axs[0])
(M2_2.u-M2_2.u_filtered).sel(time=slice(None,t1)).plot(ax=axs[1])
(M3_2.u-M3_2.u_filtered).sel(time=slice(None,t1)).plot(ax=axs[2])

axs[0].axvline(np.datetime64('2001-01-07T22')+pd.Timedelta(float(10*24/f1.values),'H'))
axs[1].axvline(np.datetime64('2001-01-07T20')+pd.Timedelta(float(10*24/f2.values),'H'))
axs[1].axvline(np.datetime64('2001-01-07T20')+pd.Timedelta(float(10*24/f1.values),'H'),c='orange')
axs[2].axvline(np.datetime64('2001-01-07T20')+pd.Timedelta(float(10*24/f3.values),'H'))
axs[2].axvline(np.datetime64('2001-01-07T20')+pd.Timedelta(float(10*24/f1.values),'H'),c='orange')

for ax in axs:
    ax.set_title('');ax.set_xlabel('')
    ax.axvline(np.datetime64('2001-01-07T22'))
    #ax.axvline(np.datetime64('2001-01-08T17'))

# %%
t0='2001-01-07T22'
Dt = pd.Timedelta(float(24/f1.values),'H')

fig,axs=plt.subplots(1,3,figsize=(10,5),sharey=True)
#M1
ax=axs[0]
(M1_2.u-M1_2.u_filtered).sel(time=t0).plot(ax=axs[0],y='depth',label='t0')
(M1_2.u-M1_2.u_filtered).sel(time=np.datetime64(t0)+5*Dt,method='nearest').plot(ax=ax,y='depth',label=r't0+5 $f_{M1}$')
(M1_2.u-M1_2.u_filtered).sel(time=np.datetime64(t0)+10*Dt,method='nearest').plot(ax=ax,y='depth',label=r't0+10 $f_{M1}$')
ax.legend()
#M2
ax=axs[1]
(M2_2.u-M2_2.u_filtered).sel(time=t0).plot(ax=ax,y='depth')
(M2_2.u-M2_2.u_filtered).sel(time=np.datetime64(t0)+5*Dt,method='nearest').plot(ax=ax,y='depth')
(M2_2.u-M2_2.u_filtered).sel(time=np.datetime64(t0)+10*Dt,method='nearest').plot(ax=ax,y='depth')
#M3
ax=axs[2]
(M3_2.u-M3_2.u_filtered).sel(time=t0).plot(ax=ax,y='depth')
(M3_2.u-M3_2.u_filtered).sel(time=np.datetime64(t0)+5*Dt,method='nearest').plot(ax=ax,y='depth')
(M3_2.u-M3_2.u_filtered).sel(time=np.datetime64(t0)+10*Dt,method='nearest').plot(ax=ax,y='depth')

for i,ax in enumerate(axs):
    ax.grid();ax.set_title('M%s'%(i+1))

# %%
f1 = 24*3600*ut.coriolis(M1lat)/(2*np.pi)
f2 = 24*3600*ut.coriolis(M2lat)/(2*np.pi)
f3 = 24*3600*ut.coriolis(M3lat)/(2*np.pi)
fig,axs=plt.subplots(3,1,figsize=(12,9),sharex=True)
(M1.u-M1.u_filtered).sel(time=slice(None,t1)).plot(ax=axs[0])
(M2.u-M2.u_filtered).sel(time=slice(None,t1)).plot(ax=axs[1])
(M3.u-M3.u_filtered).sel(time=slice(None,t1)).plot(ax=axs[2])

axs[0].axvline(np.datetime64('2001-01-07T22')+pd.Timedelta(float(10*24/f1.values),'H'))
axs[1].axvline(np.datetime64('2001-01-07T20')+pd.Timedelta(float(10*24/f2.values),'H'))
axs[1].axvline(np.datetime64('2001-01-07T20')+pd.Timedelta(float(10*24/f1.values),'H'),c='orange')
axs[2].axvline(np.datetime64('2001-01-07T20')+pd.Timedelta(float(10*24/f3.values),'H'))
axs[2].axvline(np.datetime64('2001-01-07T20')+pd.Timedelta(float(10*24/f1.values),'H'),c='orange')

for ax in axs:
    ax.set_title('');ax.set_xlabel('')
    ax.axvline(np.datetime64('2001-01-07T22'))

# %%
t0='2001-01-07T22'
Dt = pd.Timedelta(float(24/f1.values),'H')

fig,axs=plt.subplots(1,3,figsize=(10,5),sharey=True)
#M1
ax=axs[0]
(M1.u-M1.u_filtered).sel(time=t0).plot(ax=axs[0],y='depth',label='t0')
(M1.u-M1.u_filtered).sel(time=np.datetime64(t0)+5*Dt,method='nearest').plot(ax=ax,y='depth',label=r't0+5 $f_{M1}$')
(M1.u-M1.u_filtered).sel(time=np.datetime64(t0)+10*Dt,method='nearest').plot(ax=ax,y='depth',label=r't0+10 $f_{M1}$')
ax.legend()
#M2
ax=axs[1]
(M2.u-M2.u_filtered).sel(time=t0).plot(ax=ax,y='depth')
(M2.u-M2.u_filtered).sel(time=np.datetime64(t0)+5*Dt,method='nearest').plot(ax=ax,y='depth')
(M2.u-M2.u_filtered).sel(time=np.datetime64(t0)+10*Dt,method='nearest').plot(ax=ax,y='depth')
#M3
ax=axs[2]
(M3.u-M3.u_filtered).sel(time=t0).plot(ax=ax,y='depth')
(M3.u-M3.u_filtered).sel(time=np.datetime64(t0)+5*Dt,method='nearest').plot(ax=ax,y='depth')
(M3.u-M3.u_filtered).sel(time=np.datetime64(t0)+10*Dt,method='nearest').plot(ax=ax,y='depth')

for i,ax in enumerate(axs):
    ax.grid();ax.set_title('M%s'%(i+1))

# %%
Dt = pd.Timedelta(float(24/f1.values),'H')
f1_2 = 24*3600*ut.coriolis(M1lat_2)/(2*np.pi)
Dt_2 = pd.Timedelta(float(24/f1_2.values),'H')

fig,axs=plt.subplots(1,3,figsize=(10,5),sharey=True)
ax=axs[0]
(M1.u-M1.u_filtered).sel(time=t0).plot(ax=ax,y='depth',label='M1')
(M2.u-M2.u_filtered).sel(time=t0).plot(ax=ax,y='depth',label='M2')
(M3.u-M3.u_filtered).sel(time=t0).plot(ax=ax,y='depth',label='M3')

ax=axs[1]
(M1.u-M1.u_filtered).sel(time=np.datetime64(t0)+5*Dt,method='nearest').plot(ax=ax,y='depth',label='M1')
(M2.u-M2.u_filtered).sel(time=np.datetime64(t0)+5*Dt,method='nearest').plot(ax=ax,y='depth',label='M2')
(M3.u-M3.u_filtered).sel(time=np.datetime64(t0)+5*Dt,method='nearest').plot(ax=ax,y='depth',label='M3')

ax=axs[2]
(M1.u-M1.u_filtered).sel(time=np.datetime64(t0)+10*Dt,method='nearest').plot(ax=ax,y='depth',label='M1')
(M2.u-M2.u_filtered).sel(time=np.datetime64(t0)+10*Dt,method='nearest').plot(ax=ax,y='depth',label='M2')
(M3.u-M3.u_filtered).sel(time=np.datetime64(t0)+10*Dt,method='nearest').plot(ax=ax,y='depth',label='M3')

for i,ax in enumerate(axs):
    ax.grid();ax.set_title('')

# %%
fig, axs = plt.subplots(ncols=3,
                        subplot_kw={'projection': ccrs.LambertConformal(central_longitude=-27.4,central_latitude=61.5)},
                        figsize=(15,5))
(ds_filt.u-ds_filt.u_filtered).sel(time=t0,method='nearest').sel(depth=300,method='nearest').plot.contourf(ax=axs[0],
                                                                             x='lon', y='lat',
                                                                             vmin=-6e-2, vmax=6e-1,
                                                                             cmap=cmocean.cm.balance,
                                                                             transform=ccrs.PlateCarree(),
                                                                            levels=51,
                                                                             add_labels=False,add_colorbar=False)

(ds_filt.u-ds_filt.u_filtered).sel(time=np.datetime64(t0)+5*Dt,method='nearest').sel(depth=300,method='nearest').plot.contourf(ax=axs[1],
                                                                             x='lon', y='lat',
                                                                             vmin=-6e-2, vmax=6e-1,
                                                                             cmap=cmocean.cm.balance,
                                                                             transform=ccrs.PlateCarree(),
                                                                            levels=51,
                                                                             add_labels=False,add_colorbar=False)

(ds_filt.u-ds_filt.u_filtered).sel(time=np.datetime64(t0)+10*Dt,method='nearest').sel(depth=300,method='nearest').plot.contourf(ax=axs[2],
                                                                             x='lon', y='lat',
                                                                             vmin=-6e-2, vmax=6e-1,
                                                                             cmap=cmocean.cm.balance,
                                                                             transform=ccrs.PlateCarree(),
                                                                            levels=51,
                                                                             add_labels=False,add_colorbar=False)

for ax in axs:
    ax.scatter(M2lon,M2lat,c='r',transform=ccrs.PlateCarree());ax.scatter(M3lon,M3lat,c='r',transform=ccrs.PlateCarree());
    ax.scatter(M1lon,M1lat,c='r',transform=ccrs.PlateCarree());
    ax.scatter(M2lon_2,M2lat_2,c='g',transform=ccrs.PlateCarree());ax.scatter(M3lon_2,M3lat_2,c='g',transform=ccrs.PlateCarree());
    ax.scatter(M1lon_2,M1lat_2,c='g',transform=ccrs.PlateCarree());

# %%
X = [L_avg05.Lr_bc.sel(mode=1,time=slice(None,t1)).mean(),L_avg.Lr_bc.sel(mode=1,time=slice(None,t1)).mean(),
     L_avg2.Lr_bc.sel(mode=1,time=slice(None,t1)).mean()]
Y = [L_avg05.l_IW.isel(lv=0).sel(time=slice(None,t1)).mean(),L_avg.l_IW.isel(lv=0).sel(time=slice(None,t1)).mean(),L_avg2.l_IW.isel(lv=0).sel(time=slice(None,t1)).mean()]
Xbis = [L_avg05.Lr_bc.sel(time=slice(None,t1)).mean(),L_avg.Lr_bc.sel(time=slice(None,t1)).mean(),L_avg2.Lr_bc.sel(time=slice(None,t1)).mean()]
Ybis = [L_avg05.l_IW.sel(time=slice(None,t1)).mean(),L_avg.l_IW.sel(time=slice(None,t1)).mean(),L_avg2.l_IW.sel(time=slice(None,t1)).mean()]

# %%
plt.scatter(X,Y,c=['b','r','g'])
plt.grid()
plt.figure()
plt.scatter(Xbis,Ybis,c=['b','r','g'],marker='v')
plt.grid()

# %%
print(L_avg05.Lr_bc.sel(mode=1,time=slice('2001-01-08','2001-01-13')).mean().values)
print(L_avg05.lambda1_IW.sel(time=slice('2001-01-08','2001-01-13')).mean().values)

print(L_avg.Lr_bc.sel(mode=1,time=slice('2001-01-08','2001-01-13')).mean().values)
print(L_avg.lambda1_IW.sel(time=slice('2001-01-08','2001-01-13')).mean().values)

print(L_avg2.Lr_bc.sel(mode=1,time=slice('2001-01-08','2001-01-13')).mean().values)
print(L_avg2.lambda1_IW.sel(time=slice('2001-01-08','2001-01-13')).mean().values)
# Out:
# 8.557993931864283
# 0.4830858778207276
# 8.46033693269211
# 0.4783047876475117
# 8.37330725775151
# 0.47170603067438177

# %%
print(L_avg05.Lr_bc.sel(mode=1,time=slice(None,'2001-01-08')).mean().values)
print(L_avg05.lambda1_IW.sel(time=slice('2001-01-08','2001-01-13')).mean().values)

print(L_avg.Lr_bc.sel(mode=1,time=slice(None,'2001-01-08')).mean().values)
print(L_avg.lambda1_IW.sel(time=slice('2001-01-08','2001-01-13')).mean().values)

print(L_avg2.Lr_bc.sel(mode=1,time=slice(None,'2001-01-08')).mean().values)
print(L_avg2.lambda1_IW.sel(time=slice('2001-01-08','2001-01-13')).mean().values)
# Out:
# 12.426486361021315
# 0.4830858778207276
# 12.214705052036788
# 0.4783047876475117
# 11.809830025751094
# 0.47170603067438177
